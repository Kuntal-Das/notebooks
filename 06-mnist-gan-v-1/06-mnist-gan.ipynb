# %% [markdown]
# # Generative Adverserial Networks in PyTorch
#
# Deep neural networks are used mainly for supervised learning: classification or regression. Generative Adverserial Networks or GANs, however, use neural networks for a very different purpose: Generative modeling
#
# > Generative modeling is an unsupervised learning task in machine learning that involves automatically discovering and learning the regularities or patterns in input data in such a way that the model can be used to generate or output new examples that plausibly could have been drawn from the original dataset. - [Source](https://machinelearningmastery.com/what-are-generative-adversarial-networks-gans/)
#
# While there are many approaches used for generative modeling, a Generative Adverserial Network takes the following approach:
#
# ![GAN Flowchart](https://i.imgur.com/6NMdO9u.png)
#
# There are two neural networks: a *Generator* and a *Discriminator*. The generator generates a "fake" sample given a random vector/matrix, and the discriminator attempts to detect whether a given sample is "real" (picked from the training data) or "fake" (generated by the generator). Training happens in tandem: we train the discriminator for a few epochs, then train the generator for a few epochs, and repeat. This way both the generator and the discriminator get better at doing their jobs. This rather simple approach can lead to some astounding results. The following images ([source](https://machinelearningmastery.com/resources-for-getting-started-with-generative-adversarial-networks/)), for instances, were all generated using GANs:
#
# <img src="https://3qeqpr26caki16dnhd19sv6by6v-wpengine.netdna-ssl.com/wp-content/uploads/2019/04/Example-of-Photorealistic-Human-Faces-Generated-by-a-GAN.png" alt="gans_results" width="480">
#
#
# GANs however, can be notoriously difficult to train, and are extremely sensitive to hyperparameters, activation functions and regularization. In this tutorial, we'll train a GAN to generate images of handwritten digits similar to those from the MNIST database.
#
# <img src="https://i.imgur.com/CAYnuo1.jpg" width="360" >
#
# Most of the code for this tutorial has been borrowed for this excellent repository of PyTorch tutorials: [github.com/yunjey/pytorch-tutorial](https://github.com/yunjey/pytorch-tutorial). Here's what we're going to do:
#
# * Define the problem statement
# * Load the data (with transforms and normalization)
#     * Denormalize for visual inspection of samples
# * Define the Discriminator network
#     * Study the activation function: Leaky ReLU
# * Define the Generator network
#     * Explain the output activation function: TanH
#     * Look at some sample outputs
# * Define losses, optimizers and helper functions for training
#     * For discriminator
#     * For generator
# * Train the model
#     * Save intermediate generated images to file
# * Look at some outputs
# * Save the models
# * Commit to Jovian.ml

# %% [markdown]
# ## Load the Data
#
# We begin by downloading and importing the data as a PyTorch dataset using the `MNIST` helper class from `torchvision.datasets`.

# %%
import torch
import torchvision
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import MNIST

mnist = MNIST(root='data', 
              train=True, 
              download=True,
              transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw
# Processing...
# Done!
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/mnist.py:480: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %% [markdown]
# Note that we are are transforming the pixel values from the range `[0, 1]` to the range `[-1, 1]`. The reason for doing this will become clear when define the generator network. Let's look at a sample tensor from the data.

# %%
img, label = mnist[0]
print('Label: ', label)
print(img[:,10:15,10:15])
torch.min(img), torch.max(img)
# Out:
# Label:  5
#
#
# tensor([[[-0.9922,  0.2078,  0.9843, -0.2941, -1.0000],
#          [-1.0000,  0.0902,  0.9843,  0.4902, -0.9843],
#          [-1.0000, -0.9137,  0.4902,  0.9843, -0.4510],
#          [-1.0000, -1.0000, -0.7255,  0.8902,  0.7647],
#          [-1.0000, -1.0000, -1.0000, -0.3647,  0.8824]]])
# (tensor(-1.), tensor(1.))

# %% [markdown]
# As expected, the pixel values range from -1 to 1. Let's define a helper to denormalize and view the images. This function will also be useful for viewing the generated images.

# %%
def denorm(x):
    out = (x + 1) / 2
    return out.clamp(0, 1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

img_norm = denorm(img)
plt.imshow(img_norm[0], cmap='gray')
print('Label:', label)
# Out:
# Label: 5

# %% [markdown]
# Finally, let's create a dataloader to load the images in batches.

# %%
from torch.utils.data import DataLoader

batch_size = 100
data_loader = DataLoader(mnist, batch_size, shuffle=True)

# %%
for img_batch, label_batch in data_loader:
    print('first batch')
    print(img_batch.shape)
    plt.imshow(img_batch[0][0], cmap='gray')
    print(label_batch)
    break
# Out:
# first batch
# torch.Size([100, 1, 28, 28])
# tensor([6, 9, 9, 7, 8, 6, 4, 8, 3, 6, 3, 4, 4, 5, 4, 8, 9, 1, 8, 0, 5, 8, 4, 8,
#         7, 2, 6, 4, 6, 2, 3, 4, 8, 8, 9, 3, 4, 2, 8, 9, 9, 6, 5, 3, 8, 6, 3, 5,
#         4, 2, 4, 4, 0, 2, 8, 7, 2, 8, 0, 6, 3, 4, 9, 6, 3, 3, 7, 4, 3, 4, 3, 1,
#         5, 6, 6, 4, 6, 6, 5, 0, 7, 4, 0, 5, 8, 9, 2, 7, 3, 9, 7, 7, 8, 6, 0, 4,
#         3, 6, 5, 5])

# %% [markdown]
# We'll also create a `device` which can be used to move the data and models to a GPU, if one is available.

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## Discriminator Network
#
# The discriminator takes an image as input, and tries to classify it as "real" or "generated". In this sense, it's like any other neural network. While we can use a CNN for the discriminator, we'll use a simple feedforward network with 3 linear layers to keep things since. We'll treat each 28x28 image as a vector of size 784.

# %%
image_size = 784
hidden_size = 256

# %%
import torch.nn as nn

D = nn.Sequential(
    nn.Linear(image_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, 1),
    nn.Sigmoid())

# %% [markdown]
# We use the Leaky ReLU activation for the discriminator.
#
# <img src="https://cdn-images-1.medium.com/max/1600/1*ypsvQH7kvtI2BhzR2eT_Sw.png" width="420">
#
#
# >  Different from the regular ReLU function, Leaky ReLU allows the pass of a small gradient signal for negative values. As a result, it makes the gradients from the discriminator flows stronger into the generator. Instead of passing a gradient (slope) of 0 in the back-prop pass, it passes a small negative gradient.  - [Source](https://sthalles.github.io/advanced_gans/)
#
# Just like any other binary classification model, the output of the discriminator is a single number between 0 and 1, which can be interpreted as the probability of the input image being fake i.e. generated.
#
# Let's move the discriminator model to the chosen device.

# %%
D.to(device);

# %% [markdown]
# ## Generator Network
#
# The input to the generator is typically a vector or a matrix which is used as a seed for generating an image. Once again, to keep things simple, we'll use a feedfoward neural network with 3 layers, and the output will be a vector of size 784, which can be transformed to a 28x28 px image.

# %%
latent_size = 64

# %%
G = nn.Sequential(
    nn.Linear(latent_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, image_size),
    nn.Tanh())

# %% [markdown]
# We use the TanH activation function for the output layer of the generator.
#
# <img src="https://nic.schraudolph.org/teach/NNcourse/figs/tanh.gif" width="420" >
#
# > "The ReLU activation (Nair & Hinton, 2010) is used in the generator with the exception of the output layer which uses the Tanh function. We observed that using a bounded activation allowed the model to learn more quickly to saturate and cover the color space of the training distribution. Within the discriminator we found the leaky rectified activation (Maas et al., 2013) (Xu et al., 2015) to work well, especially for higher resolution modeling." - [Source](https://stackoverflow.com/questions/41489907/generative-adversarial-networks-tanh)
#
#
# Note that since the outputs of the TanH activation lie in the range `[-1,1]`, we have applied the same transformation to the images in the training dataset. Let's generate an output vector using the generator and view it as an image by transforming and denormalizing the output.

# %%
y = G(torch.randn(2, latent_size))
gen_imgs = denorm(y.reshape((-1, 28,28)).detach())

# %%
plt.imshow(gen_imgs[0], cmap='gray');

# %%
plt.imshow(gen_imgs[1], cmap='gray');

# %% [markdown]
# As one might expect, the output from the generator is basically random noise. Let's define a helper function which can save a batch of outputs from the generator to a file.
#
# Let's move the generator to the chosen device.

# %%
G.to(device);

# %% [markdown]
# ## Discriminator Training
#
# Since the discriminator is a binary classification model, we can use the binary cross entropy loss function to quantify how well it is able to differentiate between real and generated images.
#
# <img src="https://image.slidesharecdn.com/chrishokamp-dublinnlp3-160805110319/95/task-based-learning-for-nlp-going-beyond-cross-entropy-chris-hokamp-10-638.jpg?cb=1470395213" width="420" >

# %%
criterion = nn.BCELoss()
d_optimizer = torch.optim.Adam(D.parameters(), lr=0.0002)

# %% [markdown]
# Let's define helper functions to reset gradients and  train the discriminator.

# %%
def reset_grad():
    d_optimizer.zero_grad()
    g_optimizer.zero_grad()

def train_discriminator(images):
    # Create the labels which are later used as input for the BCE loss
    real_labels = torch.ones(batch_size, 1).to(device)
    fake_labels = torch.zeros(batch_size, 1).to(device)
        
    # Loss for real images
    outputs = D(images)
    d_loss_real = criterion(outputs, real_labels)
    real_score = outputs

    # Loss for fake images
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    outputs = D(fake_images)
    d_loss_fake = criterion(outputs, fake_labels)
    fake_score = outputs

    # Combine losses
    d_loss = d_loss_real + d_loss_fake
    # Reset gradients
    reset_grad()
    # Compute gradients
    d_loss.backward()
    # Adjust the parameters using backprop
    d_optimizer.step()
    
    return d_loss, real_score, fake_score

# %% [markdown]
# Here are the steps involved in training the discriminator.
#
# - We expect the discriminator to output 1 if the image was picked from the real MNIST dataset, and 0 if it was generated.
#
# - We first pass a batch of real images, and compute the loss, setting the target labels to 1.
#
# - Then, we generate a batch of fake images using the generator, pass them into the discriminator, and compute the loss, setting the target labels to 0.
#
# - Finally we add the two losses and use the overall loss to perform gradient descent to adjust the weights of the discriminator.
#
# It's important to note that we don't change the weights of the generator model while training the discriminator (`d_optimizer` only affects the `D.parameters()`)

# %% [markdown]
# ## Generator Training
#
# Since the outputs of the generator are images, it's not obvious how we can train the generator. This is where we employ a rather elegant trick, which is to use the discriminator as a part of the loss function. Here's how it works:
#
# - We generate a batch of images using the generator, pass the into the discriminator.
#
# - We calculate the loss by setting the target labels to 1 i.e. real. We do this because the generator's objective is to "fool" the discriminator.
#
# - We use the loss to perform gradient descent i.e. change the weights of the generator, so it gets better at generating real-like images.
#
# Here's what this looks like in code.

# %%
g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002)

# %%
def train_generator():
    # Generate fake images and calculate loss
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    labels = torch.ones(batch_size, 1).to(device)
    g_loss = criterion(D(fake_images), labels)

    # Backprop and optimize
    reset_grad()
    g_loss.backward()
    g_optimizer.step()
    return g_loss, fake_images

# %% [markdown]
# ## Training the Model
#
# Let's create a directory where we can save intermediate outputs from the generator to visually inspect the progress of the model

# %%
import os

sample_dir = 'samples'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %% [markdown]
# Let's save a batch of real images that we can use for visual comparision while looking at the generated images.

# %%
from IPython.display import Image
from torchvision.utils import save_image

# Save some real images
for images, _ in data_loader:
    images = images.reshape(images.size(0), 1, 28, 28)
    save_image(denorm(images), os.path.join(sample_dir, 'real_images.png'), nrow=10)
    break
   
Image(os.path.join(sample_dir, 'real_images.png'))

# %% [markdown]
# We'll also define a helper function to save a batch of generated images to disk at the end of every epoch. We'll use a fixed set of input vectors to the generator to see how the individual generated images evolve over time as we train the model.

# %%
sample_vectors = torch.randn(batch_size, latent_size).to(device)

def save_fake_images(index):
    fake_images = G(sample_vectors)
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    fake_fname = 'fake_images-{0:0=4d}.png'.format(index)
    print('Saving', fake_fname)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)
    
# Before training
save_fake_images(0)
Image(os.path.join(sample_dir, 'fake_images-0000.png'))
# Out:
# Saving fake_images-0000.png

# %% [markdown]
# We are now ready to train the model. In each epoch, we train the discriminator first, and then the generator. The training might take a while if you're not using a GPU.

# %%
# %%time

num_epochs = 300
total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        # Load a batch & transform to vectors
        images = images.reshape(batch_size, -1).to(device)
        
        # Train the discriminator and generator
        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()
        
        # Inspect the losses
        if (i+1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}' 
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(), 
                          real_score.mean().item(), fake_score.mean().item()))
        
    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# Epoch [0/300], Step [200/600], d_loss: 0.0470, g_loss: 4.0851, D(x): 0.99, D(G(z)): 0.04
# Epoch [0/300], Step [400/600], d_loss: 0.0827, g_loss: 5.5041, D(x): 0.98, D(G(z)): 0.05
# Epoch [0/300], Step [600/600], d_loss: 0.1101, g_loss: 4.0503, D(x): 0.95, D(G(z)): 0.06
# Saving fake_images-0001.png
# Epoch [1/300], Step [200/600], d_loss: 0.0968, g_loss: 4.8559, D(x): 0.97, D(G(z)): 0.05
# Epoch [1/300], Step [400/600], d_loss: 0.1405, g_loss: 3.8689, D(x): 0.94, D(G(z)): 0.05
# Epoch [1/300], Step [600/600], d_loss: 0.5670, g_loss: 3.8210, D(x): 0.91, D(G(z)): 0.28
# Saving fake_images-0002.png
# Epoch [2/300], Step [200/600], d_loss: 0.6662, g_loss: 3.7035, D(x): 0.87, D(G(z)): 0.26
# Epoch [2/300], Step [400/600], d_loss: 0.3396, g_loss: 3.4559, D(x): 0.90, D(G(z)): 0.15
# Epoch [2/300], Step [600/600], d_loss: 0.3404, g_loss: 3.3326, D(x): 0.89, D(G(z)): 0.11
# Saving fake_images-0003.png
# Epoch [3/300], Step [200/600], d_loss: 0.2340, g_loss: 3.2848, D(x): 0.93, D(G(z)): 0.11
# Epoch [3/300], Step [400/600], d_loss: 0.4751, g_loss: 2.7104, D(x): 0.82, D(G(z)): 0.13
# Epoch [3/300], Step [600/600], d_loss: 1.8182, g_loss: 2.0073, D(x): 0.68, D(G(z)): 0.55
# Saving fake_images-0004.png
# Epoch [4/300], Step [200/600], d_loss: 0.2636, g_loss: 4.4997, D(x): 0.91, D(G(z)): 0.07
# Epoch [4/300], Step [400/600], d_loss: 0.2113, g_loss: 5.2010, D(x): 0.91, D(G(z)): 0.07
# Epoch [4/300], Step [600/600], d_loss: 0.1519, g_loss: 2.9552, D(x): 0.96, D(G(z)): 0.09
# Saving fake_images-0005.png
# Epoch [5/300], Step [200/600], d_loss: 0.1448, g_loss: 3.9747, D(x): 0.98, D(G(z)): 0.10
# Epoch [5/300], Step [400/600], d_loss: 0.2320, g_loss: 3.8500, D(x): 0.92, D(G(z)): 0.07
# Epoch [5/300], Step [600/600], d_loss: 0.1371, g_loss: 3.7428, D(x): 0.93, D(G(z)): 0.03
# Saving fake_images-0006.png
# Epoch [6/300], Step [200/600], d_loss: 0.0610, g_loss: 5.0725, D(x): 0.99, D(G(z)): 0.03
# Epoch [6/300], Step [400/600], d_loss: 0.1962, g_loss: 5.1805, D(x): 0.92, D(G(z)): 0.03
# Epoch [6/300], Step [600/600], d_loss: 0.0883, g_loss: 6.4173, D(x): 0.95, D(G(z)): 0.01
# Saving fake_images-0007.png
# Epoch [7/300], Step [200/600], d_loss: 0.1451, g_loss: 5.0552, D(x): 0.96, D(G(z)): 0.06
# Epoch [7/300], Step [400/600], d_loss: 0.1229, g_loss: 3.9044, D(x): 0.95, D(G(z)): 0.03
# Epoch [7/300], Step [600/600], d_loss: 0.1553, g_loss: 3.9550, D(x): 0.93, D(G(z)): 0.03
# Saving fake_images-0008.png
# Epoch [8/300], Step [200/600], d_loss: 0.2449, g_loss: 5.7083, D(x): 0.91, D(G(z)): 0.03
# Epoch [8/300], Step [400/600], d_loss: 0.2204, g_loss: 5.0686, D(x): 0.95, D(G(z)): 0.08
# Epoch [8/300], Step [600/600], d_loss: 0.2033, g_loss: 4.8143, D(x): 0.91, D(G(z)): 0.03
# Saving fake_images-0009.png
# Epoch [9/300], Step [200/600], d_loss: 0.1916, g_loss: 7.1054, D(x): 0.95, D(G(z)): 0.03
# Epoch [9/300], Step [400/600], d_loss: 0.4186, g_loss: 3.1589, D(x): 0.91, D(G(z)): 0.09
# Epoch [9/300], Step [600/600], d_loss: 0.2038, g_loss: 3.3504, D(x): 0.95, D(G(z)): 0.10
# Saving fake_images-0010.png
# Epoch [10/300], Step [200/600], d_loss: 0.3660, g_loss: 3.0400, D(x): 0.90, D(G(z)): 0.13
# Epoch [10/300], Step [400/600], d_loss: 0.2193, g_loss: 5.3812, D(x): 0.94, D(G(z)): 0.10
# Epoch [10/300], Step [600/600], d_loss: 0.2713, g_loss: 3.0903, D(x): 0.90, D(G(z)): 0.08
# Saving fake_images-0011.png
# Epoch [11/300], Step [200/600], d_loss: 0.4325, g_loss: 3.7951, D(x): 0.85, D(G(z)): 0.11
# Epoch [11/300], Step [400/600], d_loss: 0.7170, g_loss: 3.6063, D(x): 0.80, D(G(z)): 0.03
# Epoch [11/300], Step [600/600], d_loss: 0.2367, g_loss: 4.4816, D(x): 0.92, D(G(z)): 0.04
# Saving fake_images-0012.png
# Epoch [12/300], Step [200/600], d_loss: 0.1140, g_loss: 4.2718, D(x): 0.96, D(G(z)): 0.06
# Epoch [12/300], Step [400/600], d_loss: 0.1258, g_loss: 3.7719, D(x): 0.95, D(G(z)): 0.04
# Epoch [12/300], Step [600/600], d_loss: 0.1499, g_loss: 3.1374, D(x): 0.97, D(G(z)): 0.08
# Saving fake_images-0013.png
# Epoch [13/300], Step [200/600], d_loss: 0.2549, g_loss: 4.7789, D(x): 0.96, D(G(z)): 0.10
# Epoch [13/300], Step [400/600], d_loss: 0.2166, g_loss: 4.1638, D(x): 0.95, D(G(z)): 0.08
# Epoch [13/300], Step [600/600], d_loss: 0.1582, g_loss: 6.0981, D(x): 0.94, D(G(z)): 0.02
# Saving fake_images-0014.png
# Epoch [14/300], Step [200/600], d_loss: 0.1851, g_loss: 4.0511, D(x): 0.94, D(G(z)): 0.05
# Epoch [14/300], Step [400/600], d_loss: 0.1711, g_loss: 5.6195, D(x): 0.98, D(G(z)): 0.09
# Epoch [14/300], Step [600/600], d_loss: 0.1510, g_loss: 4.5471, D(x): 0.96, D(G(z)): 0.08
# Saving fake_images-0015.png
# Epoch [15/300], Step [200/600], d_loss: 0.4309, g_loss: 3.9255, D(x): 0.88, D(G(z)): 0.05
# Epoch [15/300], Step [400/600], d_loss: 0.1853, g_loss: 6.8646, D(x): 0.98, D(G(z)): 0.09
# Epoch [15/300], Step [600/600], d_loss: 0.2364, g_loss: 5.0581, D(x): 0.98, D(G(z)): 0.15
# Saving fake_images-0016.png
# Epoch [16/300], Step [200/600], d_loss: 0.1764, g_loss: 6.8435, D(x): 0.97, D(G(z)): 0.09
# Epoch [16/300], Step [400/600], d_loss: 0.5899, g_loss: 4.8980, D(x): 0.83, D(G(z)): 0.05
# Epoch [16/300], Step [600/600], d_loss: 0.1238, g_loss: 5.1377, D(x): 0.95, D(G(z)): 0.01
# Saving fake_images-0017.png
# Epoch [17/300], Step [200/600], d_loss: 0.2894, g_loss: 4.3846, D(x): 0.95, D(G(z)): 0.13
# Epoch [17/300], Step [400/600], d_loss: 0.2480, g_loss: 4.9281, D(x): 0.89, D(G(z)): 0.05
# Epoch [17/300], Step [600/600], d_loss: 0.5892, g_loss: 5.4331, D(x): 0.86, D(G(z)): 0.07
# Saving fake_images-0018.png
# Epoch [18/300], Step [200/600], d_loss: 0.2075, g_loss: 5.9417, D(x): 0.96, D(G(z)): 0.08
# Epoch [18/300], Step [400/600], d_loss: 0.2155, g_loss: 3.9912, D(x): 0.94, D(G(z)): 0.10
# Epoch [18/300], Step [600/600], d_loss: 0.3201, g_loss: 7.3582, D(x): 0.89, D(G(z)): 0.01
# Saving fake_images-0019.png
# Epoch [19/300], Step [200/600], d_loss: 0.1485, g_loss: 4.0376, D(x): 0.96, D(G(z)): 0.08
# Epoch [19/300], Step [400/600], d_loss: 0.2657, g_loss: 4.8480, D(x): 0.94, D(G(z)): 0.07
# Epoch [19/300], Step [600/600], d_loss: 0.2384, g_loss: 6.5850, D(x): 0.90, D(G(z)): 0.01
# Saving fake_images-0020.png
# Epoch [20/300], Step [200/600], d_loss: 0.2075, g_loss: 4.4086, D(x): 0.95, D(G(z)): 0.05
# Epoch [20/300], Step [400/600], d_loss: 0.2573, g_loss: 6.0655, D(x): 0.93, D(G(z)): 0.07
# Epoch [20/300], Step [600/600], d_loss: 0.2509, g_loss: 5.5349, D(x): 0.91, D(G(z)): 0.01
# Saving fake_images-0021.png
# Epoch [21/300], Step [200/600], d_loss: 0.3559, g_loss: 4.6489, D(x): 0.90, D(G(z)): 0.04
# Epoch [21/300], Step [400/600], d_loss: 0.3413, g_loss: 5.9619, D(x): 0.87, D(G(z)): 0.03
# Epoch [21/300], Step [600/600], d_loss: 0.3254, g_loss: 4.9169, D(x): 0.88, D(G(z)): 0.06
# Saving fake_images-0022.png
# Epoch [22/300], Step [200/600], d_loss: 0.2633, g_loss: 4.9743, D(x): 0.89, D(G(z)): 0.06
# Epoch [22/300], Step [400/600], d_loss: 0.2164, g_loss: 4.2146, D(x): 0.90, D(G(z)): 0.04
# Epoch [22/300], Step [600/600], d_loss: 0.3008, g_loss: 3.9955, D(x): 0.95, D(G(z)): 0.14
# Saving fake_images-0023.png
# Epoch [23/300], Step [200/600], d_loss: 0.3084, g_loss: 4.0591, D(x): 0.92, D(G(z)): 0.10
# Epoch [23/300], Step [400/600], d_loss: 0.2675, g_loss: 5.4361, D(x): 0.90, D(G(z)): 0.06
# Epoch [23/300], Step [600/600], d_loss: 0.2656, g_loss: 4.9918, D(x): 0.92, D(G(z)): 0.09
# Saving fake_images-0024.png
# Epoch [24/300], Step [200/600], d_loss: 0.6271, g_loss: 4.7354, D(x): 0.97, D(G(z)): 0.29
# Epoch [24/300], Step [400/600], d_loss: 0.3590, g_loss: 5.4126, D(x): 0.86, D(G(z)): 0.02
# Epoch [24/300], Step [600/600], d_loss: 0.2204, g_loss: 3.7093, D(x): 0.93, D(G(z)): 0.07
# Saving fake_images-0025.png
# Epoch [25/300], Step [200/600], d_loss: 0.2675, g_loss: 4.9743, D(x): 0.90, D(G(z)): 0.04
# Epoch [25/300], Step [400/600], d_loss: 0.2990, g_loss: 3.4382, D(x): 0.87, D(G(z)): 0.03
# Epoch [25/300], Step [600/600], d_loss: 0.4013, g_loss: 2.7343, D(x): 0.90, D(G(z)): 0.12
# Saving fake_images-0026.png
# Epoch [26/300], Step [200/600], d_loss: 0.4245, g_loss: 2.9413, D(x): 0.93, D(G(z)): 0.19
# Epoch [26/300], Step [400/600], d_loss: 0.3507, g_loss: 3.6211, D(x): 0.93, D(G(z)): 0.17
# Epoch [26/300], Step [600/600], d_loss: 0.5080, g_loss: 3.7692, D(x): 0.87, D(G(z)): 0.11
# Saving fake_images-0027.png
# Epoch [27/300], Step [200/600], d_loss: 0.4279, g_loss: 3.5601, D(x): 0.89, D(G(z)): 0.15
# Epoch [27/300], Step [400/600], d_loss: 0.3047, g_loss: 3.6741, D(x): 0.94, D(G(z)): 0.16
# Epoch [27/300], Step [600/600], d_loss: 0.3580, g_loss: 3.3544, D(x): 0.87, D(G(z)): 0.07
# Saving fake_images-0028.png
# Epoch [28/300], Step [200/600], d_loss: 0.4720, g_loss: 3.1794, D(x): 0.88, D(G(z)): 0.14
# Epoch [28/300], Step [400/600], d_loss: 0.4149, g_loss: 3.3516, D(x): 0.89, D(G(z)): 0.12
# Epoch [28/300], Step [600/600], d_loss: 0.3631, g_loss: 3.3145, D(x): 0.87, D(G(z)): 0.09
# Saving fake_images-0029.png
# Epoch [29/300], Step [200/600], d_loss: 0.5328, g_loss: 4.1237, D(x): 0.84, D(G(z)): 0.08
# Epoch [29/300], Step [400/600], d_loss: 0.3529, g_loss: 2.8912, D(x): 0.91, D(G(z)): 0.17
# Epoch [29/300], Step [600/600], d_loss: 0.3676, g_loss: 3.6432, D(x): 0.89, D(G(z)): 0.12
# Saving fake_images-0030.png
# Epoch [30/300], Step [200/600], d_loss: 0.4226, g_loss: 4.5186, D(x): 0.87, D(G(z)): 0.11
# Epoch [30/300], Step [400/600], d_loss: 0.3169, g_loss: 3.8749, D(x): 0.89, D(G(z)): 0.08
# Epoch [30/300], Step [600/600], d_loss: 0.3748, g_loss: 3.9484, D(x): 0.90, D(G(z)): 0.14
# Saving fake_images-0031.png
# Epoch [31/300], Step [200/600], d_loss: 0.4618, g_loss: 2.8302, D(x): 0.91, D(G(z)): 0.22
# Epoch [31/300], Step [400/600], d_loss: 0.4830, g_loss: 3.9624, D(x): 0.90, D(G(z)): 0.21
# Epoch [31/300], Step [600/600], d_loss: 0.4836, g_loss: 2.5528, D(x): 0.88, D(G(z)): 0.17
# Saving fake_images-0032.png
# Epoch [32/300], Step [200/600], d_loss: 0.3223, g_loss: 3.3288, D(x): 0.93, D(G(z)): 0.15
# Epoch [32/300], Step [400/600], d_loss: 0.3243, g_loss: 4.2493, D(x): 0.91, D(G(z)): 0.12
# Epoch [32/300], Step [600/600], d_loss: 0.3184, g_loss: 3.8448, D(x): 0.92, D(G(z)): 0.13
# Saving fake_images-0033.png
# Epoch [33/300], Step [200/600], d_loss: 0.2665, g_loss: 4.1423, D(x): 0.93, D(G(z)): 0.06
# Epoch [33/300], Step [400/600], d_loss: 0.2663, g_loss: 3.3656, D(x): 0.94, D(G(z)): 0.11
# Epoch [33/300], Step [600/600], d_loss: 0.3418, g_loss: 3.2957, D(x): 0.90, D(G(z)): 0.10
# Saving fake_images-0034.png
# Epoch [34/300], Step [200/600], d_loss: 0.4451, g_loss: 4.7415, D(x): 0.88, D(G(z)): 0.11
# Epoch [34/300], Step [400/600], d_loss: 0.5340, g_loss: 3.6489, D(x): 0.83, D(G(z)): 0.12
# Epoch [34/300], Step [600/600], d_loss: 0.4138, g_loss: 2.8804, D(x): 0.82, D(G(z)): 0.08
# Saving fake_images-0035.png
# Epoch [35/300], Step [200/600], d_loss: 0.4326, g_loss: 1.9715, D(x): 0.85, D(G(z)): 0.11
# Epoch [35/300], Step [400/600], d_loss: 0.4729, g_loss: 3.0378, D(x): 0.93, D(G(z)): 0.24
# Epoch [35/300], Step [600/600], d_loss: 0.4716, g_loss: 3.7048, D(x): 0.93, D(G(z)): 0.23
# Saving fake_images-0036.png
# Epoch [36/300], Step [200/600], d_loss: 0.4492, g_loss: 2.5772, D(x): 0.84, D(G(z)): 0.09
# Epoch [36/300], Step [400/600], d_loss: 0.5573, g_loss: 3.4595, D(x): 0.89, D(G(z)): 0.27
# Epoch [36/300], Step [600/600], d_loss: 0.7841, g_loss: 2.8927, D(x): 0.73, D(G(z)): 0.12
# Saving fake_images-0037.png
# Epoch [37/300], Step [200/600], d_loss: 0.4010, g_loss: 3.0038, D(x): 0.88, D(G(z)): 0.14
# Epoch [37/300], Step [400/600], d_loss: 0.3664, g_loss: 3.1502, D(x): 0.85, D(G(z)): 0.11
# Epoch [37/300], Step [600/600], d_loss: 0.7359, g_loss: 3.0889, D(x): 0.83, D(G(z)): 0.21
# Saving fake_images-0038.png
# Epoch [38/300], Step [200/600], d_loss: 0.5658, g_loss: 2.5880, D(x): 0.85, D(G(z)): 0.18
# Epoch [38/300], Step [400/600], d_loss: 0.5158, g_loss: 3.1158, D(x): 0.84, D(G(z)): 0.15
# Epoch [38/300], Step [600/600], d_loss: 0.7344, g_loss: 2.3842, D(x): 0.75, D(G(z)): 0.12
# Saving fake_images-0039.png
# Epoch [39/300], Step [200/600], d_loss: 0.4370, g_loss: 2.3779, D(x): 0.91, D(G(z)): 0.19
# Epoch [39/300], Step [400/600], d_loss: 0.5399, g_loss: 2.5447, D(x): 0.80, D(G(z)): 0.10
# Epoch [39/300], Step [600/600], d_loss: 0.5026, g_loss: 2.4738, D(x): 0.85, D(G(z)): 0.17
# Saving fake_images-0040.png
# Epoch [40/300], Step [200/600], d_loss: 0.4417, g_loss: 3.5684, D(x): 0.80, D(G(z)): 0.10
# Epoch [40/300], Step [400/600], d_loss: 0.3238, g_loss: 2.4373, D(x): 0.94, D(G(z)): 0.19
# Epoch [40/300], Step [600/600], d_loss: 0.8145, g_loss: 2.4398, D(x): 0.76, D(G(z)): 0.18
# Saving fake_images-0041.png
# Epoch [41/300], Step [200/600], d_loss: 0.2963, g_loss: 2.5837, D(x): 0.92, D(G(z)): 0.15
# Epoch [41/300], Step [400/600], d_loss: 0.5233, g_loss: 3.1837, D(x): 0.85, D(G(z)): 0.18
# Epoch [41/300], Step [600/600], d_loss: 0.3387, g_loss: 3.0507, D(x): 0.88, D(G(z)): 0.10
# Saving fake_images-0042.png
# Epoch [42/300], Step [200/600], d_loss: 0.4581, g_loss: 3.5821, D(x): 0.84, D(G(z)): 0.10
# Epoch [42/300], Step [400/600], d_loss: 0.3316, g_loss: 3.1299, D(x): 0.85, D(G(z)): 0.06
# Epoch [42/300], Step [600/600], d_loss: 0.3665, g_loss: 3.1532, D(x): 0.90, D(G(z)): 0.16
# Saving fake_images-0043.png
# Epoch [43/300], Step [200/600], d_loss: 0.6346, g_loss: 2.8133, D(x): 0.84, D(G(z)): 0.23
# Epoch [43/300], Step [400/600], d_loss: 0.5231, g_loss: 4.0685, D(x): 0.78, D(G(z)): 0.09
# Epoch [43/300], Step [600/600], d_loss: 0.5420, g_loss: 2.7195, D(x): 0.88, D(G(z)): 0.23
# Saving fake_images-0044.png
# Epoch [44/300], Step [200/600], d_loss: 0.4998, g_loss: 3.0338, D(x): 0.86, D(G(z)): 0.20
# Epoch [44/300], Step [400/600], d_loss: 0.6031, g_loss: 3.0029, D(x): 0.86, D(G(z)): 0.25
# Epoch [44/300], Step [600/600], d_loss: 0.4993, g_loss: 3.0709, D(x): 0.77, D(G(z)): 0.08
# Saving fake_images-0045.png
# Epoch [45/300], Step [200/600], d_loss: 0.6061, g_loss: 2.1905, D(x): 0.86, D(G(z)): 0.25
# Epoch [45/300], Step [400/600], d_loss: 0.7747, g_loss: 3.2343, D(x): 0.77, D(G(z)): 0.17
# Epoch [45/300], Step [600/600], d_loss: 0.7209, g_loss: 2.1706, D(x): 0.77, D(G(z)): 0.17
# Saving fake_images-0046.png
# Epoch [46/300], Step [200/600], d_loss: 0.7722, g_loss: 2.6121, D(x): 0.72, D(G(z)): 0.11
# Epoch [46/300], Step [400/600], d_loss: 0.5340, g_loss: 2.9653, D(x): 0.81, D(G(z)): 0.10
# Epoch [46/300], Step [600/600], d_loss: 0.4274, g_loss: 2.6614, D(x): 0.84, D(G(z)): 0.15
# Saving fake_images-0047.png
# Epoch [47/300], Step [200/600], d_loss: 0.5817, g_loss: 2.0699, D(x): 0.81, D(G(z)): 0.14
# Epoch [47/300], Step [400/600], d_loss: 0.4788, g_loss: 2.6700, D(x): 0.84, D(G(z)): 0.14
# Epoch [47/300], Step [600/600], d_loss: 0.5989, g_loss: 2.1617, D(x): 0.83, D(G(z)): 0.24
# Saving fake_images-0048.png
# Epoch [48/300], Step [200/600], d_loss: 0.4139, g_loss: 2.2199, D(x): 0.86, D(G(z)): 0.15
# Epoch [48/300], Step [400/600], d_loss: 0.7065, g_loss: 2.0748, D(x): 0.78, D(G(z)): 0.16
# Epoch [48/300], Step [600/600], d_loss: 0.5594, g_loss: 2.9912, D(x): 0.74, D(G(z)): 0.06
# Saving fake_images-0049.png
# Epoch [49/300], Step [200/600], d_loss: 0.7717, g_loss: 2.6109, D(x): 0.73, D(G(z)): 0.16
# Epoch [49/300], Step [400/600], d_loss: 0.5505, g_loss: 2.3329, D(x): 0.81, D(G(z)): 0.17
# Epoch [49/300], Step [600/600], d_loss: 0.7141, g_loss: 2.9891, D(x): 0.80, D(G(z)): 0.21
# Saving fake_images-0050.png
# Epoch [50/300], Step [200/600], d_loss: 0.6612, g_loss: 1.9956, D(x): 0.84, D(G(z)): 0.22
# Epoch [50/300], Step [400/600], d_loss: 0.4346, g_loss: 3.0506, D(x): 0.87, D(G(z)): 0.17
# Epoch [50/300], Step [600/600], d_loss: 0.6435, g_loss: 2.2533, D(x): 0.82, D(G(z)): 0.22
# Saving fake_images-0051.png
# Epoch [51/300], Step [200/600], d_loss: 0.8847, g_loss: 1.8307, D(x): 0.87, D(G(z)): 0.36
# Epoch [51/300], Step [400/600], d_loss: 0.6009, g_loss: 2.6899, D(x): 0.85, D(G(z)): 0.20
# Epoch [51/300], Step [600/600], d_loss: 0.5082, g_loss: 2.5042, D(x): 0.92, D(G(z)): 0.26
# Saving fake_images-0052.png
# Epoch [52/300], Step [200/600], d_loss: 0.6655, g_loss: 3.2459, D(x): 0.84, D(G(z)): 0.25
# Epoch [52/300], Step [400/600], d_loss: 0.5458, g_loss: 2.2458, D(x): 0.85, D(G(z)): 0.20
# Epoch [52/300], Step [600/600], d_loss: 0.4286, g_loss: 3.1164, D(x): 0.84, D(G(z)): 0.14
# Saving fake_images-0053.png
# Epoch [53/300], Step [200/600], d_loss: 0.4436, g_loss: 3.0438, D(x): 0.80, D(G(z)): 0.09
# Epoch [53/300], Step [400/600], d_loss: 0.6050, g_loss: 3.6742, D(x): 0.77, D(G(z)): 0.10
# Epoch [53/300], Step [600/600], d_loss: 0.4929, g_loss: 3.3215, D(x): 0.87, D(G(z)): 0.20
# Saving fake_images-0054.png
# Epoch [54/300], Step [200/600], d_loss: 0.2833, g_loss: 4.0593, D(x): 0.95, D(G(z)): 0.14
# Epoch [54/300], Step [400/600], d_loss: 0.7426, g_loss: 2.8611, D(x): 0.74, D(G(z)): 0.16
# Epoch [54/300], Step [600/600], d_loss: 0.6890, g_loss: 3.3497, D(x): 0.78, D(G(z)): 0.15
# Saving fake_images-0055.png
# Epoch [55/300], Step [200/600], d_loss: 0.5914, g_loss: 2.7683, D(x): 0.85, D(G(z)): 0.23
# Epoch [55/300], Step [400/600], d_loss: 0.4888, g_loss: 2.9176, D(x): 0.82, D(G(z)): 0.13
# Epoch [55/300], Step [600/600], d_loss: 0.4470, g_loss: 3.2241, D(x): 0.84, D(G(z)): 0.14
# Saving fake_images-0056.png
# Epoch [56/300], Step [200/600], d_loss: 0.6714, g_loss: 3.0873, D(x): 0.72, D(G(z)): 0.05
# Epoch [56/300], Step [400/600], d_loss: 0.4474, g_loss: 2.9595, D(x): 0.89, D(G(z)): 0.20
# Epoch [56/300], Step [600/600], d_loss: 0.5093, g_loss: 2.8627, D(x): 0.79, D(G(z)): 0.09
# Saving fake_images-0057.png
# Epoch [57/300], Step [200/600], d_loss: 0.4905, g_loss: 2.8240, D(x): 0.87, D(G(z)): 0.19
# Epoch [57/300], Step [400/600], d_loss: 0.6477, g_loss: 2.9676, D(x): 0.79, D(G(z)): 0.18
# Epoch [57/300], Step [600/600], d_loss: 0.5492, g_loss: 2.4492, D(x): 0.80, D(G(z)): 0.17
# Saving fake_images-0058.png
# Epoch [58/300], Step [200/600], d_loss: 0.4290, g_loss: 2.4793, D(x): 0.89, D(G(z)): 0.20
# Epoch [58/300], Step [400/600], d_loss: 0.7199, g_loss: 1.8984, D(x): 0.83, D(G(z)): 0.28
# Epoch [58/300], Step [600/600], d_loss: 0.7380, g_loss: 2.3305, D(x): 0.81, D(G(z)): 0.24
# Saving fake_images-0059.png
# Epoch [59/300], Step [200/600], d_loss: 0.5110, g_loss: 3.0673, D(x): 0.84, D(G(z)): 0.18
# Epoch [59/300], Step [400/600], d_loss: 0.5073, g_loss: 2.5954, D(x): 0.90, D(G(z)): 0.23
# Epoch [59/300], Step [600/600], d_loss: 0.7647, g_loss: 2.0688, D(x): 0.76, D(G(z)): 0.23
# Saving fake_images-0060.png
# Epoch [60/300], Step [200/600], d_loss: 0.4816, g_loss: 2.4824, D(x): 0.83, D(G(z)): 0.18
# Epoch [60/300], Step [400/600], d_loss: 0.5901, g_loss: 2.9356, D(x): 0.84, D(G(z)): 0.26
# Epoch [60/300], Step [600/600], d_loss: 0.5958, g_loss: 2.6804, D(x): 0.82, D(G(z)): 0.18
# Saving fake_images-0061.png
# Epoch [61/300], Step [200/600], d_loss: 0.5190, g_loss: 3.1537, D(x): 0.80, D(G(z)): 0.14
# Epoch [61/300], Step [400/600], d_loss: 0.7005, g_loss: 2.0634, D(x): 0.80, D(G(z)): 0.21
# Epoch [61/300], Step [600/600], d_loss: 0.9071, g_loss: 2.3715, D(x): 0.68, D(G(z)): 0.21
# Saving fake_images-0062.png
# Epoch [62/300], Step [200/600], d_loss: 0.6453, g_loss: 2.4256, D(x): 0.79, D(G(z)): 0.19
# Epoch [62/300], Step [400/600], d_loss: 0.5948, g_loss: 2.4038, D(x): 0.82, D(G(z)): 0.22
# Epoch [62/300], Step [600/600], d_loss: 0.8834, g_loss: 1.5170, D(x): 0.76, D(G(z)): 0.27
# Saving fake_images-0063.png
# Epoch [63/300], Step [200/600], d_loss: 0.6394, g_loss: 2.2098, D(x): 0.77, D(G(z)): 0.18
# Epoch [63/300], Step [400/600], d_loss: 0.7563, g_loss: 2.6134, D(x): 0.72, D(G(z)): 0.19
# Epoch [63/300], Step [600/600], d_loss: 0.6200, g_loss: 1.9122, D(x): 0.86, D(G(z)): 0.24
# Saving fake_images-0064.png
# Epoch [64/300], Step [200/600], d_loss: 0.5878, g_loss: 2.6903, D(x): 0.80, D(G(z)): 0.16
# Epoch [64/300], Step [400/600], d_loss: 0.7078, g_loss: 1.8099, D(x): 0.76, D(G(z)): 0.25
# Epoch [64/300], Step [600/600], d_loss: 0.7791, g_loss: 1.5005, D(x): 0.78, D(G(z)): 0.25
# Saving fake_images-0065.png
# Epoch [65/300], Step [200/600], d_loss: 0.5775, g_loss: 2.1658, D(x): 0.87, D(G(z)): 0.27
# Epoch [65/300], Step [400/600], d_loss: 0.6830, g_loss: 2.1797, D(x): 0.80, D(G(z)): 0.25
# Epoch [65/300], Step [600/600], d_loss: 0.6510, g_loss: 2.5115, D(x): 0.74, D(G(z)): 0.15
# Saving fake_images-0066.png
# Epoch [66/300], Step [200/600], d_loss: 0.5664, g_loss: 2.0829, D(x): 0.81, D(G(z)): 0.23
# Epoch [66/300], Step [400/600], d_loss: 0.5621, g_loss: 2.3169, D(x): 0.81, D(G(z)): 0.18
# Epoch [66/300], Step [600/600], d_loss: 0.7537, g_loss: 2.6022, D(x): 0.86, D(G(z)): 0.32
# Saving fake_images-0067.png
# Epoch [67/300], Step [200/600], d_loss: 0.8513, g_loss: 1.8595, D(x): 0.69, D(G(z)): 0.21
# Epoch [67/300], Step [400/600], d_loss: 0.6669, g_loss: 2.2954, D(x): 0.84, D(G(z)): 0.28
# Epoch [67/300], Step [600/600], d_loss: 0.4960, g_loss: 3.5015, D(x): 0.85, D(G(z)): 0.19
# Saving fake_images-0068.png
# Epoch [68/300], Step [200/600], d_loss: 0.8981, g_loss: 1.7267, D(x): 0.79, D(G(z)): 0.32
# Epoch [68/300], Step [400/600], d_loss: 0.8155, g_loss: 1.6605, D(x): 0.90, D(G(z)): 0.38
# Epoch [68/300], Step [600/600], d_loss: 0.5960, g_loss: 2.0717, D(x): 0.89, D(G(z)): 0.27
# Saving fake_images-0069.png
# Epoch [69/300], Step [200/600], d_loss: 0.6683, g_loss: 2.7380, D(x): 0.80, D(G(z)): 0.21
# Epoch [69/300], Step [400/600], d_loss: 0.6327, g_loss: 2.5235, D(x): 0.79, D(G(z)): 0.19
# Epoch [69/300], Step [600/600], d_loss: 0.8087, g_loss: 2.0890, D(x): 0.72, D(G(z)): 0.23
# Saving fake_images-0070.png
# Epoch [70/300], Step [200/600], d_loss: 0.9118, g_loss: 2.2766, D(x): 0.75, D(G(z)): 0.25
# Epoch [70/300], Step [400/600], d_loss: 0.7565, g_loss: 1.3699, D(x): 0.79, D(G(z)): 0.26
# Epoch [70/300], Step [600/600], d_loss: 0.7281, g_loss: 1.8380, D(x): 0.85, D(G(z)): 0.31
# Saving fake_images-0071.png
# Epoch [71/300], Step [200/600], d_loss: 0.5169, g_loss: 3.0899, D(x): 0.79, D(G(z)): 0.12
# Epoch [71/300], Step [400/600], d_loss: 0.5953, g_loss: 2.3778, D(x): 0.76, D(G(z)): 0.16
# Epoch [71/300], Step [600/600], d_loss: 0.7099, g_loss: 2.6945, D(x): 0.73, D(G(z)): 0.16
# Saving fake_images-0072.png
# Epoch [72/300], Step [200/600], d_loss: 0.6109, g_loss: 2.8392, D(x): 0.79, D(G(z)): 0.20
# Epoch [72/300], Step [400/600], d_loss: 0.5136, g_loss: 1.6122, D(x): 0.81, D(G(z)): 0.19
# Epoch [72/300], Step [600/600], d_loss: 0.6954, g_loss: 2.4952, D(x): 0.74, D(G(z)): 0.19
# Saving fake_images-0073.png
# Epoch [73/300], Step [200/600], d_loss: 0.6435, g_loss: 2.1946, D(x): 0.71, D(G(z)): 0.13
# Epoch [73/300], Step [400/600], d_loss: 0.6512, g_loss: 1.7580, D(x): 0.80, D(G(z)): 0.24
# Epoch [73/300], Step [600/600], d_loss: 0.6678, g_loss: 2.1092, D(x): 0.80, D(G(z)): 0.26
# Saving fake_images-0074.png
# Epoch [74/300], Step [200/600], d_loss: 0.8046, g_loss: 1.9074, D(x): 0.80, D(G(z)): 0.32
# Epoch [74/300], Step [400/600], d_loss: 0.6432, g_loss: 2.0008, D(x): 0.81, D(G(z)): 0.24
# Epoch [74/300], Step [600/600], d_loss: 0.5946, g_loss: 2.3701, D(x): 0.75, D(G(z)): 0.12
# Saving fake_images-0075.png
# Epoch [75/300], Step [200/600], d_loss: 0.9389, g_loss: 1.8313, D(x): 0.72, D(G(z)): 0.33
# Epoch [75/300], Step [400/600], d_loss: 0.6233, g_loss: 2.2797, D(x): 0.82, D(G(z)): 0.24
# Epoch [75/300], Step [600/600], d_loss: 0.7793, g_loss: 1.9037, D(x): 0.66, D(G(z)): 0.14
# Saving fake_images-0076.png
# Epoch [76/300], Step [200/600], d_loss: 0.8601, g_loss: 2.1245, D(x): 0.68, D(G(z)): 0.18
# Epoch [76/300], Step [400/600], d_loss: 0.8416, g_loss: 1.9216, D(x): 0.75, D(G(z)): 0.28
# Epoch [76/300], Step [600/600], d_loss: 0.5782, g_loss: 2.4607, D(x): 0.79, D(G(z)): 0.20
# Saving fake_images-0077.png
# Epoch [77/300], Step [200/600], d_loss: 0.8786, g_loss: 2.1843, D(x): 0.71, D(G(z)): 0.23
# Epoch [77/300], Step [400/600], d_loss: 0.6679, g_loss: 2.7670, D(x): 0.77, D(G(z)): 0.22
# Epoch [77/300], Step [600/600], d_loss: 0.8303, g_loss: 1.9418, D(x): 0.69, D(G(z)): 0.21
# Saving fake_images-0078.png
# Epoch [78/300], Step [200/600], d_loss: 0.7012, g_loss: 2.2080, D(x): 0.75, D(G(z)): 0.19
# Epoch [78/300], Step [400/600], d_loss: 0.6519, g_loss: 1.7821, D(x): 0.80, D(G(z)): 0.24
# Epoch [78/300], Step [600/600], d_loss: 0.7322, g_loss: 2.0696, D(x): 0.78, D(G(z)): 0.24
# Saving fake_images-0079.png
# Epoch [79/300], Step [200/600], d_loss: 0.6209, g_loss: 1.9282, D(x): 0.82, D(G(z)): 0.25
# Epoch [79/300], Step [400/600], d_loss: 0.7130, g_loss: 2.1750, D(x): 0.79, D(G(z)): 0.28
# Epoch [79/300], Step [600/600], d_loss: 0.4891, g_loss: 2.3283, D(x): 0.85, D(G(z)): 0.21
# Saving fake_images-0080.png
# Epoch [80/300], Step [200/600], d_loss: 0.7921, g_loss: 2.4355, D(x): 0.72, D(G(z)): 0.18
# Epoch [80/300], Step [400/600], d_loss: 0.8868, g_loss: 2.1902, D(x): 0.71, D(G(z)): 0.22
# Epoch [80/300], Step [600/600], d_loss: 0.6111, g_loss: 2.7426, D(x): 0.84, D(G(z)): 0.22
# Saving fake_images-0081.png
# Epoch [81/300], Step [200/600], d_loss: 0.8213, g_loss: 3.4559, D(x): 0.73, D(G(z)): 0.16
# Epoch [81/300], Step [400/600], d_loss: 0.7846, g_loss: 1.8346, D(x): 0.82, D(G(z)): 0.32
# Epoch [81/300], Step [600/600], d_loss: 0.6281, g_loss: 2.5424, D(x): 0.76, D(G(z)): 0.15
# Saving fake_images-0082.png
# Epoch [82/300], Step [200/600], d_loss: 0.8264, g_loss: 1.5232, D(x): 0.76, D(G(z)): 0.25
# Epoch [82/300], Step [400/600], d_loss: 0.7964, g_loss: 2.3175, D(x): 0.82, D(G(z)): 0.32
# Epoch [82/300], Step [600/600], d_loss: 0.8273, g_loss: 1.8362, D(x): 0.74, D(G(z)): 0.25
# Saving fake_images-0083.png
# Epoch [83/300], Step [200/600], d_loss: 0.6446, g_loss: 2.2004, D(x): 0.82, D(G(z)): 0.21
# Epoch [83/300], Step [400/600], d_loss: 0.8265, g_loss: 1.6808, D(x): 0.66, D(G(z)): 0.14
# Epoch [83/300], Step [600/600], d_loss: 0.7234, g_loss: 2.3125, D(x): 0.71, D(G(z)): 0.17
# Saving fake_images-0084.png
# Epoch [84/300], Step [200/600], d_loss: 0.7022, g_loss: 2.0491, D(x): 0.78, D(G(z)): 0.25
# Epoch [84/300], Step [400/600], d_loss: 0.7859, g_loss: 1.9298, D(x): 0.72, D(G(z)): 0.22
# Epoch [84/300], Step [600/600], d_loss: 0.8239, g_loss: 1.7734, D(x): 0.70, D(G(z)): 0.22
# Saving fake_images-0085.png
# Epoch [85/300], Step [200/600], d_loss: 0.6595, g_loss: 2.4937, D(x): 0.79, D(G(z)): 0.24
# Epoch [85/300], Step [400/600], d_loss: 0.7662, g_loss: 1.8553, D(x): 0.75, D(G(z)): 0.24
# Epoch [85/300], Step [600/600], d_loss: 0.5749, g_loss: 2.4205, D(x): 0.74, D(G(z)): 0.12
# Saving fake_images-0086.png
# Epoch [86/300], Step [200/600], d_loss: 0.8354, g_loss: 1.9567, D(x): 0.83, D(G(z)): 0.36
# Epoch [86/300], Step [400/600], d_loss: 0.8080, g_loss: 1.9305, D(x): 0.75, D(G(z)): 0.28
# Epoch [86/300], Step [600/600], d_loss: 0.8828, g_loss: 2.3385, D(x): 0.83, D(G(z)): 0.38
# Saving fake_images-0087.png
# Epoch [87/300], Step [200/600], d_loss: 0.3667, g_loss: 2.6442, D(x): 0.88, D(G(z)): 0.17
# Epoch [87/300], Step [400/600], d_loss: 0.6433, g_loss: 2.3254, D(x): 0.81, D(G(z)): 0.24
# Epoch [87/300], Step [600/600], d_loss: 0.8348, g_loss: 2.0399, D(x): 0.71, D(G(z)): 0.20
# Saving fake_images-0088.png
# Epoch [88/300], Step [200/600], d_loss: 0.7767, g_loss: 1.7623, D(x): 0.83, D(G(z)): 0.33
# Epoch [88/300], Step [400/600], d_loss: 0.8739, g_loss: 2.1554, D(x): 0.71, D(G(z)): 0.21
# Epoch [88/300], Step [600/600], d_loss: 0.9694, g_loss: 1.9602, D(x): 0.68, D(G(z)): 0.25
# Saving fake_images-0089.png
# Epoch [89/300], Step [200/600], d_loss: 0.6997, g_loss: 1.9012, D(x): 0.74, D(G(z)): 0.21
# Epoch [89/300], Step [400/600], d_loss: 0.7446, g_loss: 1.9980, D(x): 0.75, D(G(z)): 0.24
# Epoch [89/300], Step [600/600], d_loss: 0.8170, g_loss: 1.7339, D(x): 0.77, D(G(z)): 0.30
# Saving fake_images-0090.png
# Epoch [90/300], Step [200/600], d_loss: 0.6025, g_loss: 1.9819, D(x): 0.86, D(G(z)): 0.26
# Epoch [90/300], Step [400/600], d_loss: 0.7373, g_loss: 2.2209, D(x): 0.79, D(G(z)): 0.29
# Epoch [90/300], Step [600/600], d_loss: 0.7547, g_loss: 2.0580, D(x): 0.76, D(G(z)): 0.24
# Saving fake_images-0091.png
# Epoch [91/300], Step [200/600], d_loss: 0.5820, g_loss: 1.7220, D(x): 0.77, D(G(z)): 0.19
# Epoch [91/300], Step [400/600], d_loss: 0.5289, g_loss: 2.3162, D(x): 0.80, D(G(z)): 0.18
# Epoch [91/300], Step [600/600], d_loss: 0.7560, g_loss: 1.9261, D(x): 0.75, D(G(z)): 0.25
# Saving fake_images-0092.png
# Epoch [92/300], Step [200/600], d_loss: 0.9706, g_loss: 1.6054, D(x): 0.80, D(G(z)): 0.41
# Epoch [92/300], Step [400/600], d_loss: 0.7721, g_loss: 1.7991, D(x): 0.73, D(G(z)): 0.23
# Epoch [92/300], Step [600/600], d_loss: 0.7150, g_loss: 1.9243, D(x): 0.74, D(G(z)): 0.22
# Saving fake_images-0093.png
# Epoch [93/300], Step [200/600], d_loss: 0.6480, g_loss: 1.5046, D(x): 0.81, D(G(z)): 0.27
# Epoch [93/300], Step [400/600], d_loss: 0.7609, g_loss: 2.4937, D(x): 0.75, D(G(z)): 0.26
# Epoch [93/300], Step [600/600], d_loss: 0.5778, g_loss: 2.4884, D(x): 0.81, D(G(z)): 0.18
# Saving fake_images-0094.png
# Epoch [94/300], Step [200/600], d_loss: 0.6946, g_loss: 2.0940, D(x): 0.76, D(G(z)): 0.21
# Epoch [94/300], Step [400/600], d_loss: 0.5646, g_loss: 2.1356, D(x): 0.81, D(G(z)): 0.23
# Epoch [94/300], Step [600/600], d_loss: 0.8345, g_loss: 1.6679, D(x): 0.75, D(G(z)): 0.27
# Saving fake_images-0095.png
# Epoch [95/300], Step [200/600], d_loss: 0.8262, g_loss: 2.3927, D(x): 0.75, D(G(z)): 0.28
# Epoch [95/300], Step [400/600], d_loss: 0.8305, g_loss: 1.3532, D(x): 0.78, D(G(z)): 0.32
# Epoch [95/300], Step [600/600], d_loss: 0.6900, g_loss: 2.2517, D(x): 0.73, D(G(z)): 0.19
# Saving fake_images-0096.png
# Epoch [96/300], Step [200/600], d_loss: 0.6771, g_loss: 1.8304, D(x): 0.78, D(G(z)): 0.24
# Epoch [96/300], Step [400/600], d_loss: 0.6500, g_loss: 2.1979, D(x): 0.83, D(G(z)): 0.27
# Epoch [96/300], Step [600/600], d_loss: 0.6934, g_loss: 1.9300, D(x): 0.77, D(G(z)): 0.25
# Saving fake_images-0097.png
# Epoch [97/300], Step [200/600], d_loss: 0.7370, g_loss: 1.7356, D(x): 0.77, D(G(z)): 0.27
# Epoch [97/300], Step [400/600], d_loss: 0.9598, g_loss: 2.0459, D(x): 0.68, D(G(z)): 0.26
# Epoch [97/300], Step [600/600], d_loss: 0.8194, g_loss: 2.3505, D(x): 0.75, D(G(z)): 0.25
# Saving fake_images-0098.png
# Epoch [98/300], Step [200/600], d_loss: 0.9394, g_loss: 2.1066, D(x): 0.63, D(G(z)): 0.21
# Epoch [98/300], Step [400/600], d_loss: 0.5880, g_loss: 2.2121, D(x): 0.76, D(G(z)): 0.17
# Epoch [98/300], Step [600/600], d_loss: 0.7710, g_loss: 1.9596, D(x): 0.80, D(G(z)): 0.29
# Saving fake_images-0099.png
# Epoch [99/300], Step [200/600], d_loss: 0.9464, g_loss: 2.1396, D(x): 0.65, D(G(z)): 0.20
# Epoch [99/300], Step [400/600], d_loss: 0.7946, g_loss: 1.9139, D(x): 0.70, D(G(z)): 0.20
# Epoch [99/300], Step [600/600], d_loss: 0.6877, g_loss: 1.5345, D(x): 0.78, D(G(z)): 0.25
# Saving fake_images-0100.png
# Epoch [100/300], Step [200/600], d_loss: 0.7990, g_loss: 2.3372, D(x): 0.69, D(G(z)): 0.19
# Epoch [100/300], Step [400/600], d_loss: 0.7951, g_loss: 1.6427, D(x): 0.77, D(G(z)): 0.31
# Epoch [100/300], Step [600/600], d_loss: 0.8614, g_loss: 2.2723, D(x): 0.68, D(G(z)): 0.24
# Saving fake_images-0101.png
# Epoch [101/300], Step [200/600], d_loss: 0.9625, g_loss: 2.1129, D(x): 0.68, D(G(z)): 0.25
# Epoch [101/300], Step [400/600], d_loss: 0.8917, g_loss: 1.8406, D(x): 0.74, D(G(z)): 0.28
# Epoch [101/300], Step [600/600], d_loss: 0.6838, g_loss: 1.7486, D(x): 0.78, D(G(z)): 0.27
# Saving fake_images-0102.png
# Epoch [102/300], Step [200/600], d_loss: 1.1833, g_loss: 1.7914, D(x): 0.63, D(G(z)): 0.22
# Epoch [102/300], Step [400/600], d_loss: 0.9680, g_loss: 1.6511, D(x): 0.68, D(G(z)): 0.27
# Epoch [102/300], Step [600/600], d_loss: 0.7737, g_loss: 1.7068, D(x): 0.71, D(G(z)): 0.21
# Saving fake_images-0103.png
# Epoch [103/300], Step [200/600], d_loss: 0.7308, g_loss: 2.1204, D(x): 0.72, D(G(z)): 0.18
# Epoch [103/300], Step [400/600], d_loss: 0.8040, g_loss: 2.0908, D(x): 0.76, D(G(z)): 0.27
# Epoch [103/300], Step [600/600], d_loss: 0.7315, g_loss: 1.7461, D(x): 0.83, D(G(z)): 0.34
# Saving fake_images-0104.png
# Epoch [104/300], Step [200/600], d_loss: 0.9428, g_loss: 1.4712, D(x): 0.72, D(G(z)): 0.31
# Epoch [104/300], Step [400/600], d_loss: 0.7935, g_loss: 1.8830, D(x): 0.74, D(G(z)): 0.25
# Epoch [104/300], Step [600/600], d_loss: 0.9079, g_loss: 1.9706, D(x): 0.65, D(G(z)): 0.22
# Saving fake_images-0105.png
# Epoch [105/300], Step [200/600], d_loss: 0.9756, g_loss: 1.9315, D(x): 0.66, D(G(z)): 0.24
# Epoch [105/300], Step [400/600], d_loss: 0.6961, g_loss: 2.2820, D(x): 0.77, D(G(z)): 0.23
# Epoch [105/300], Step [600/600], d_loss: 0.8732, g_loss: 2.4204, D(x): 0.70, D(G(z)): 0.23
# Saving fake_images-0106.png
# Epoch [106/300], Step [200/600], d_loss: 0.5737, g_loss: 2.1596, D(x): 0.77, D(G(z)): 0.18
# Epoch [106/300], Step [400/600], d_loss: 0.6304, g_loss: 1.9627, D(x): 0.83, D(G(z)): 0.27
# Epoch [106/300], Step [600/600], d_loss: 0.9398, g_loss: 1.5303, D(x): 0.71, D(G(z)): 0.31
# Saving fake_images-0107.png
# Epoch [107/300], Step [200/600], d_loss: 0.8529, g_loss: 1.5854, D(x): 0.77, D(G(z)): 0.32
# Epoch [107/300], Step [400/600], d_loss: 0.7138, g_loss: 1.7363, D(x): 0.75, D(G(z)): 0.26
# Epoch [107/300], Step [600/600], d_loss: 0.9394, g_loss: 1.7520, D(x): 0.66, D(G(z)): 0.27
# Saving fake_images-0108.png
# Epoch [108/300], Step [200/600], d_loss: 0.8209, g_loss: 2.0708, D(x): 0.76, D(G(z)): 0.31
# Epoch [108/300], Step [400/600], d_loss: 0.9414, g_loss: 1.5172, D(x): 0.75, D(G(z)): 0.35
# Epoch [108/300], Step [600/600], d_loss: 0.7640, g_loss: 1.8488, D(x): 0.75, D(G(z)): 0.27
# Saving fake_images-0109.png
# Epoch [109/300], Step [200/600], d_loss: 0.8409, g_loss: 1.8212, D(x): 0.79, D(G(z)): 0.33
# Epoch [109/300], Step [400/600], d_loss: 0.9887, g_loss: 1.8662, D(x): 0.72, D(G(z)): 0.35
# Epoch [109/300], Step [600/600], d_loss: 0.9070, g_loss: 1.4245, D(x): 0.78, D(G(z)): 0.36
# Saving fake_images-0110.png
# Epoch [110/300], Step [200/600], d_loss: 0.8932, g_loss: 1.8129, D(x): 0.71, D(G(z)): 0.27
# Epoch [110/300], Step [400/600], d_loss: 0.8171, g_loss: 1.7026, D(x): 0.72, D(G(z)): 0.26
# Epoch [110/300], Step [600/600], d_loss: 0.8529, g_loss: 2.2635, D(x): 0.69, D(G(z)): 0.21
# Saving fake_images-0111.png
# Epoch [111/300], Step [200/600], d_loss: 0.8517, g_loss: 1.7505, D(x): 0.71, D(G(z)): 0.28
# Epoch [111/300], Step [400/600], d_loss: 0.8782, g_loss: 1.5377, D(x): 0.66, D(G(z)): 0.24
# Epoch [111/300], Step [600/600], d_loss: 0.9868, g_loss: 2.0254, D(x): 0.67, D(G(z)): 0.26
# Saving fake_images-0112.png
# Epoch [112/300], Step [200/600], d_loss: 0.9730, g_loss: 1.4172, D(x): 0.71, D(G(z)): 0.31
# Epoch [112/300], Step [400/600], d_loss: 0.8470, g_loss: 1.4008, D(x): 0.77, D(G(z)): 0.30
# Epoch [112/300], Step [600/600], d_loss: 0.7123, g_loss: 1.5038, D(x): 0.85, D(G(z)): 0.32
# Saving fake_images-0113.png
# Epoch [113/300], Step [200/600], d_loss: 0.7465, g_loss: 2.0822, D(x): 0.79, D(G(z)): 0.31
# Epoch [113/300], Step [400/600], d_loss: 0.9139, g_loss: 1.7519, D(x): 0.69, D(G(z)): 0.26
# Epoch [113/300], Step [600/600], d_loss: 0.7802, g_loss: 1.5914, D(x): 0.80, D(G(z)): 0.33
# Saving fake_images-0114.png
# Epoch [114/300], Step [200/600], d_loss: 0.9967, g_loss: 1.7635, D(x): 0.69, D(G(z)): 0.32
# Epoch [114/300], Step [400/600], d_loss: 0.9715, g_loss: 1.6935, D(x): 0.75, D(G(z)): 0.36
# Epoch [114/300], Step [600/600], d_loss: 0.8687, g_loss: 1.7269, D(x): 0.78, D(G(z)): 0.33
# Saving fake_images-0115.png
# Epoch [115/300], Step [200/600], d_loss: 1.0331, g_loss: 1.6877, D(x): 0.79, D(G(z)): 0.42
# Epoch [115/300], Step [400/600], d_loss: 0.7554, g_loss: 2.0493, D(x): 0.70, D(G(z)): 0.18
# Epoch [115/300], Step [600/600], d_loss: 0.9233, g_loss: 1.5621, D(x): 0.71, D(G(z)): 0.30
# Saving fake_images-0116.png
# Epoch [116/300], Step [200/600], d_loss: 0.7423, g_loss: 1.7233, D(x): 0.71, D(G(z)): 0.19
# Epoch [116/300], Step [400/600], d_loss: 1.1279, g_loss: 1.5267, D(x): 0.67, D(G(z)): 0.35
# Epoch [116/300], Step [600/600], d_loss: 0.5944, g_loss: 1.7819, D(x): 0.85, D(G(z)): 0.28
# Saving fake_images-0117.png
# Epoch [117/300], Step [200/600], d_loss: 0.9828, g_loss: 1.6335, D(x): 0.74, D(G(z)): 0.38
# Epoch [117/300], Step [400/600], d_loss: 1.0689, g_loss: 1.7058, D(x): 0.62, D(G(z)): 0.27
# Epoch [117/300], Step [600/600], d_loss: 1.0082, g_loss: 1.6767, D(x): 0.79, D(G(z)): 0.41
# Saving fake_images-0118.png
# Epoch [118/300], Step [200/600], d_loss: 0.9379, g_loss: 1.5921, D(x): 0.68, D(G(z)): 0.28
# Epoch [118/300], Step [400/600], d_loss: 0.7986, g_loss: 1.6990, D(x): 0.71, D(G(z)): 0.26
# Epoch [118/300], Step [600/600], d_loss: 0.8556, g_loss: 1.7516, D(x): 0.79, D(G(z)): 0.33
# Saving fake_images-0119.png
# Epoch [119/300], Step [200/600], d_loss: 0.8321, g_loss: 1.6286, D(x): 0.75, D(G(z)): 0.31
# Epoch [119/300], Step [400/600], d_loss: 0.6794, g_loss: 2.0129, D(x): 0.71, D(G(z)): 0.18
# Epoch [119/300], Step [600/600], d_loss: 0.9192, g_loss: 1.8310, D(x): 0.68, D(G(z)): 0.26
# Saving fake_images-0120.png
# Epoch [120/300], Step [200/600], d_loss: 1.0021, g_loss: 1.6083, D(x): 0.56, D(G(z)): 0.15
# Epoch [120/300], Step [400/600], d_loss: 0.9741, g_loss: 1.4879, D(x): 0.73, D(G(z)): 0.33
# Epoch [120/300], Step [600/600], d_loss: 0.8764, g_loss: 1.7899, D(x): 0.75, D(G(z)): 0.30
# Saving fake_images-0121.png
# Epoch [121/300], Step [200/600], d_loss: 0.7707, g_loss: 1.6792, D(x): 0.73, D(G(z)): 0.19
# Epoch [121/300], Step [400/600], d_loss: 0.8074, g_loss: 2.0463, D(x): 0.79, D(G(z)): 0.31
# Epoch [121/300], Step [600/600], d_loss: 1.0513, g_loss: 1.7639, D(x): 0.75, D(G(z)): 0.37
# Saving fake_images-0122.png
# Epoch [122/300], Step [200/600], d_loss: 0.9078, g_loss: 1.4535, D(x): 0.75, D(G(z)): 0.37
# Epoch [122/300], Step [400/600], d_loss: 0.8068, g_loss: 1.6891, D(x): 0.73, D(G(z)): 0.25
# Epoch [122/300], Step [600/600], d_loss: 1.0778, g_loss: 1.3931, D(x): 0.69, D(G(z)): 0.35
# Saving fake_images-0123.png
# Epoch [123/300], Step [200/600], d_loss: 1.0686, g_loss: 1.7001, D(x): 0.58, D(G(z)): 0.19
# Epoch [123/300], Step [400/600], d_loss: 1.0998, g_loss: 1.5446, D(x): 0.61, D(G(z)): 0.26
# Epoch [123/300], Step [600/600], d_loss: 1.0864, g_loss: 1.4146, D(x): 0.69, D(G(z)): 0.37
# Saving fake_images-0124.png
# Epoch [124/300], Step [200/600], d_loss: 0.9386, g_loss: 1.3294, D(x): 0.69, D(G(z)): 0.28
# Epoch [124/300], Step [400/600], d_loss: 0.7696, g_loss: 1.8190, D(x): 0.76, D(G(z)): 0.29
# Epoch [124/300], Step [600/600], d_loss: 1.0064, g_loss: 1.8123, D(x): 0.65, D(G(z)): 0.24
# Saving fake_images-0125.png
# Epoch [125/300], Step [200/600], d_loss: 0.8628, g_loss: 1.7517, D(x): 0.71, D(G(z)): 0.28
# Epoch [125/300], Step [400/600], d_loss: 1.0554, g_loss: 1.5595, D(x): 0.67, D(G(z)): 0.34
# Epoch [125/300], Step [600/600], d_loss: 0.7173, g_loss: 2.1479, D(x): 0.71, D(G(z)): 0.19
# Saving fake_images-0126.png
# Epoch [126/300], Step [200/600], d_loss: 0.8733, g_loss: 1.8050, D(x): 0.71, D(G(z)): 0.30
# Epoch [126/300], Step [400/600], d_loss: 0.8583, g_loss: 2.0288, D(x): 0.71, D(G(z)): 0.24
# Epoch [126/300], Step [600/600], d_loss: 0.6628, g_loss: 2.0751, D(x): 0.73, D(G(z)): 0.19
# Saving fake_images-0127.png
# Epoch [127/300], Step [200/600], d_loss: 0.9261, g_loss: 1.4001, D(x): 0.79, D(G(z)): 0.38
# Epoch [127/300], Step [400/600], d_loss: 0.8956, g_loss: 2.2442, D(x): 0.71, D(G(z)): 0.27
# Epoch [127/300], Step [600/600], d_loss: 0.8751, g_loss: 1.7817, D(x): 0.70, D(G(z)): 0.26
# Saving fake_images-0128.png
# Epoch [128/300], Step [200/600], d_loss: 0.8524, g_loss: 1.9419, D(x): 0.71, D(G(z)): 0.29
# Epoch [128/300], Step [400/600], d_loss: 0.8241, g_loss: 2.0397, D(x): 0.76, D(G(z)): 0.28
# Epoch [128/300], Step [600/600], d_loss: 0.8642, g_loss: 1.1921, D(x): 0.75, D(G(z)): 0.31
# Saving fake_images-0129.png
# Epoch [129/300], Step [200/600], d_loss: 0.9433, g_loss: 1.9953, D(x): 0.64, D(G(z)): 0.21
# Epoch [129/300], Step [400/600], d_loss: 0.8175, g_loss: 1.4111, D(x): 0.73, D(G(z)): 0.28
# Epoch [129/300], Step [600/600], d_loss: 0.8798, g_loss: 1.3014, D(x): 0.72, D(G(z)): 0.31
# Saving fake_images-0130.png
# Epoch [130/300], Step [200/600], d_loss: 0.9176, g_loss: 1.3875, D(x): 0.70, D(G(z)): 0.29
# Epoch [130/300], Step [400/600], d_loss: 0.7746, g_loss: 1.7489, D(x): 0.69, D(G(z)): 0.20
# Epoch [130/300], Step [600/600], d_loss: 1.0087, g_loss: 1.4534, D(x): 0.72, D(G(z)): 0.33
# Saving fake_images-0131.png
# Epoch [131/300], Step [200/600], d_loss: 0.9790, g_loss: 1.4721, D(x): 0.65, D(G(z)): 0.26
# Epoch [131/300], Step [400/600], d_loss: 0.9185, g_loss: 1.7914, D(x): 0.76, D(G(z)): 0.37
# Epoch [131/300], Step [600/600], d_loss: 0.7947, g_loss: 1.7443, D(x): 0.74, D(G(z)): 0.30
# Saving fake_images-0132.png
# Epoch [132/300], Step [200/600], d_loss: 0.8218, g_loss: 1.4272, D(x): 0.78, D(G(z)): 0.31
# Epoch [132/300], Step [400/600], d_loss: 0.9735, g_loss: 1.7647, D(x): 0.76, D(G(z)): 0.36
# Epoch [132/300], Step [600/600], d_loss: 0.7663, g_loss: 1.9283, D(x): 0.75, D(G(z)): 0.24
# Saving fake_images-0133.png
# Epoch [133/300], Step [200/600], d_loss: 0.8917, g_loss: 1.5415, D(x): 0.74, D(G(z)): 0.32
# Epoch [133/300], Step [400/600], d_loss: 1.0006, g_loss: 1.4216, D(x): 0.67, D(G(z)): 0.32
# Epoch [133/300], Step [600/600], d_loss: 0.6219, g_loss: 1.8200, D(x): 0.77, D(G(z)): 0.22
# Saving fake_images-0134.png
# Epoch [134/300], Step [200/600], d_loss: 0.9284, g_loss: 1.7498, D(x): 0.75, D(G(z)): 0.31
# Epoch [134/300], Step [400/600], d_loss: 0.7156, g_loss: 1.9972, D(x): 0.69, D(G(z)): 0.17
# Epoch [134/300], Step [600/600], d_loss: 0.7457, g_loss: 2.2347, D(x): 0.77, D(G(z)): 0.27
# Saving fake_images-0135.png
# Epoch [135/300], Step [200/600], d_loss: 0.9832, g_loss: 1.5621, D(x): 0.67, D(G(z)): 0.25
# Epoch [135/300], Step [400/600], d_loss: 0.9534, g_loss: 1.7979, D(x): 0.69, D(G(z)): 0.28
# Epoch [135/300], Step [600/600], d_loss: 1.0604, g_loss: 1.6023, D(x): 0.59, D(G(z)): 0.25
# Saving fake_images-0136.png
# Epoch [136/300], Step [200/600], d_loss: 0.8368, g_loss: 1.8801, D(x): 0.69, D(G(z)): 0.23
# Epoch [136/300], Step [400/600], d_loss: 0.7832, g_loss: 1.6628, D(x): 0.74, D(G(z)): 0.28
# Epoch [136/300], Step [600/600], d_loss: 0.7660, g_loss: 1.7499, D(x): 0.69, D(G(z)): 0.23
# Saving fake_images-0137.png
# Epoch [137/300], Step [200/600], d_loss: 0.8678, g_loss: 1.4214, D(x): 0.77, D(G(z)): 0.34
# Epoch [137/300], Step [400/600], d_loss: 1.0264, g_loss: 1.3594, D(x): 0.70, D(G(z)): 0.36
# Epoch [137/300], Step [600/600], d_loss: 1.0097, g_loss: 1.7199, D(x): 0.71, D(G(z)): 0.38
# Saving fake_images-0138.png
# Epoch [138/300], Step [200/600], d_loss: 0.7525, g_loss: 1.5666, D(x): 0.77, D(G(z)): 0.29
# Epoch [138/300], Step [400/600], d_loss: 1.0159, g_loss: 1.5705, D(x): 0.70, D(G(z)): 0.36
# Epoch [138/300], Step [600/600], d_loss: 0.7895, g_loss: 1.4696, D(x): 0.77, D(G(z)): 0.29
# Saving fake_images-0139.png
# Epoch [139/300], Step [200/600], d_loss: 0.7983, g_loss: 1.6089, D(x): 0.71, D(G(z)): 0.21
# Epoch [139/300], Step [400/600], d_loss: 1.0188, g_loss: 1.8939, D(x): 0.72, D(G(z)): 0.34
# Epoch [139/300], Step [600/600], d_loss: 0.5998, g_loss: 1.7052, D(x): 0.78, D(G(z)): 0.22
# Saving fake_images-0140.png
# Epoch [140/300], Step [200/600], d_loss: 1.0285, g_loss: 1.2478, D(x): 0.62, D(G(z)): 0.28
# Epoch [140/300], Step [400/600], d_loss: 0.9350, g_loss: 2.1549, D(x): 0.73, D(G(z)): 0.34
# Epoch [140/300], Step [600/600], d_loss: 0.9290, g_loss: 1.4206, D(x): 0.63, D(G(z)): 0.22
# Saving fake_images-0141.png
# Epoch [141/300], Step [200/600], d_loss: 0.8537, g_loss: 1.8291, D(x): 0.71, D(G(z)): 0.26
# Epoch [141/300], Step [400/600], d_loss: 0.8494, g_loss: 1.5896, D(x): 0.72, D(G(z)): 0.28
# Epoch [141/300], Step [600/600], d_loss: 0.8693, g_loss: 1.8550, D(x): 0.65, D(G(z)): 0.22
# Saving fake_images-0142.png
# Epoch [142/300], Step [200/600], d_loss: 1.0462, g_loss: 1.5937, D(x): 0.66, D(G(z)): 0.32
# Epoch [142/300], Step [400/600], d_loss: 0.9325, g_loss: 1.2362, D(x): 0.78, D(G(z)): 0.39
# Epoch [142/300], Step [600/600], d_loss: 0.9049, g_loss: 1.5540, D(x): 0.74, D(G(z)): 0.33
# Saving fake_images-0143.png
# Epoch [143/300], Step [200/600], d_loss: 0.7693, g_loss: 1.7262, D(x): 0.76, D(G(z)): 0.31
# Epoch [143/300], Step [400/600], d_loss: 0.9322, g_loss: 1.3891, D(x): 0.77, D(G(z)): 0.39
# Epoch [143/300], Step [600/600], d_loss: 0.7403, g_loss: 1.5109, D(x): 0.77, D(G(z)): 0.28
# Saving fake_images-0144.png
# Epoch [144/300], Step [200/600], d_loss: 0.7332, g_loss: 2.0374, D(x): 0.74, D(G(z)): 0.24
# Epoch [144/300], Step [400/600], d_loss: 0.7516, g_loss: 1.4430, D(x): 0.72, D(G(z)): 0.27
# Epoch [144/300], Step [600/600], d_loss: 0.9526, g_loss: 1.2159, D(x): 0.71, D(G(z)): 0.34
# Saving fake_images-0145.png
# Epoch [145/300], Step [200/600], d_loss: 0.9462, g_loss: 1.5951, D(x): 0.67, D(G(z)): 0.28
# Epoch [145/300], Step [400/600], d_loss: 0.9973, g_loss: 1.5160, D(x): 0.68, D(G(z)): 0.32
# Epoch [145/300], Step [600/600], d_loss: 0.8935, g_loss: 1.3829, D(x): 0.76, D(G(z)): 0.34
# Saving fake_images-0146.png
# Epoch [146/300], Step [200/600], d_loss: 0.8779, g_loss: 1.4864, D(x): 0.72, D(G(z)): 0.33
# Epoch [146/300], Step [400/600], d_loss: 0.8080, g_loss: 1.8805, D(x): 0.73, D(G(z)): 0.27
# Epoch [146/300], Step [600/600], d_loss: 0.8705, g_loss: 1.4202, D(x): 0.73, D(G(z)): 0.31
# Saving fake_images-0147.png
# Epoch [147/300], Step [200/600], d_loss: 1.0215, g_loss: 1.5809, D(x): 0.64, D(G(z)): 0.29
# Epoch [147/300], Step [400/600], d_loss: 0.9726, g_loss: 1.3631, D(x): 0.66, D(G(z)): 0.28
# Epoch [147/300], Step [600/600], d_loss: 0.7640, g_loss: 1.9310, D(x): 0.70, D(G(z)): 0.23
# Saving fake_images-0148.png
# Epoch [148/300], Step [200/600], d_loss: 0.9280, g_loss: 1.5697, D(x): 0.69, D(G(z)): 0.30
# Epoch [148/300], Step [400/600], d_loss: 0.7842, g_loss: 2.0879, D(x): 0.74, D(G(z)): 0.25
# Epoch [148/300], Step [600/600], d_loss: 0.8395, g_loss: 1.9223, D(x): 0.75, D(G(z)): 0.32
# Saving fake_images-0149.png
# Epoch [149/300], Step [200/600], d_loss: 0.7194, g_loss: 2.3139, D(x): 0.70, D(G(z)): 0.18
# Epoch [149/300], Step [400/600], d_loss: 0.8964, g_loss: 1.4080, D(x): 0.68, D(G(z)): 0.26
# Epoch [149/300], Step [600/600], d_loss: 0.8947, g_loss: 1.9511, D(x): 0.68, D(G(z)): 0.26
# Saving fake_images-0150.png
# Epoch [150/300], Step [200/600], d_loss: 0.8396, g_loss: 1.7253, D(x): 0.68, D(G(z)): 0.22
# Epoch [150/300], Step [400/600], d_loss: 0.8663, g_loss: 1.5581, D(x): 0.78, D(G(z)): 0.35
# Epoch [150/300], Step [600/600], d_loss: 0.8355, g_loss: 1.5579, D(x): 0.69, D(G(z)): 0.24
# Saving fake_images-0151.png
# Epoch [151/300], Step [200/600], d_loss: 0.9394, g_loss: 1.6358, D(x): 0.70, D(G(z)): 0.32
# Epoch [151/300], Step [400/600], d_loss: 0.7110, g_loss: 2.1370, D(x): 0.77, D(G(z)): 0.24
# Epoch [151/300], Step [600/600], d_loss: 0.9640, g_loss: 1.2703, D(x): 0.73, D(G(z)): 0.36
# Saving fake_images-0152.png
# Epoch [152/300], Step [200/600], d_loss: 0.7680, g_loss: 1.9318, D(x): 0.73, D(G(z)): 0.26
# Epoch [152/300], Step [400/600], d_loss: 1.0344, g_loss: 1.4593, D(x): 0.77, D(G(z)): 0.40
# Epoch [152/300], Step [600/600], d_loss: 1.0076, g_loss: 1.6401, D(x): 0.68, D(G(z)): 0.32
# Saving fake_images-0153.png
# Epoch [153/300], Step [200/600], d_loss: 1.1137, g_loss: 1.4367, D(x): 0.63, D(G(z)): 0.32
# Epoch [153/300], Step [400/600], d_loss: 0.8652, g_loss: 2.1220, D(x): 0.67, D(G(z)): 0.22
# Epoch [153/300], Step [600/600], d_loss: 0.8306, g_loss: 1.3927, D(x): 0.79, D(G(z)): 0.34
# Saving fake_images-0154.png
# Epoch [154/300], Step [200/600], d_loss: 1.0595, g_loss: 1.8544, D(x): 0.65, D(G(z)): 0.31
# Epoch [154/300], Step [400/600], d_loss: 0.7744, g_loss: 2.0250, D(x): 0.76, D(G(z)): 0.29
# Epoch [154/300], Step [600/600], d_loss: 0.8927, g_loss: 1.7519, D(x): 0.67, D(G(z)): 0.24
# Saving fake_images-0155.png
# Epoch [155/300], Step [200/600], d_loss: 0.8736, g_loss: 1.6059, D(x): 0.68, D(G(z)): 0.25
# Epoch [155/300], Step [400/600], d_loss: 1.0869, g_loss: 1.6235, D(x): 0.65, D(G(z)): 0.31
# Epoch [155/300], Step [600/600], d_loss: 1.1081, g_loss: 1.1774, D(x): 0.67, D(G(z)): 0.36
# Saving fake_images-0156.png
# Epoch [156/300], Step [200/600], d_loss: 0.9082, g_loss: 1.4238, D(x): 0.68, D(G(z)): 0.26
# Epoch [156/300], Step [400/600], d_loss: 0.8218, g_loss: 1.7424, D(x): 0.72, D(G(z)): 0.28
# Epoch [156/300], Step [600/600], d_loss: 0.8296, g_loss: 1.3794, D(x): 0.72, D(G(z)): 0.26
# Saving fake_images-0157.png
# Epoch [157/300], Step [200/600], d_loss: 0.7186, g_loss: 1.8169, D(x): 0.78, D(G(z)): 0.29
# Epoch [157/300], Step [400/600], d_loss: 0.7444, g_loss: 1.4041, D(x): 0.80, D(G(z)): 0.30
# Epoch [157/300], Step [600/600], d_loss: 0.9540, g_loss: 1.7157, D(x): 0.70, D(G(z)): 0.31
# Saving fake_images-0158.png
# Epoch [158/300], Step [200/600], d_loss: 1.0253, g_loss: 2.0181, D(x): 0.64, D(G(z)): 0.30
# Epoch [158/300], Step [400/600], d_loss: 1.0697, g_loss: 1.4187, D(x): 0.62, D(G(z)): 0.29
# Epoch [158/300], Step [600/600], d_loss: 0.8898, g_loss: 1.6744, D(x): 0.69, D(G(z)): 0.27
# Saving fake_images-0159.png
# Epoch [159/300], Step [200/600], d_loss: 0.7669, g_loss: 1.9458, D(x): 0.68, D(G(z)): 0.20
# Epoch [159/300], Step [400/600], d_loss: 0.9388, g_loss: 1.4684, D(x): 0.69, D(G(z)): 0.30
# Epoch [159/300], Step [600/600], d_loss: 0.8176, g_loss: 1.6986, D(x): 0.71, D(G(z)): 0.26
# Saving fake_images-0160.png
# Epoch [160/300], Step [200/600], d_loss: 0.8307, g_loss: 1.7496, D(x): 0.71, D(G(z)): 0.25
# ...
# Saving fake_images-0206.png
# Epoch [206/300], Step [200/600], d_loss: 0.9117, g_loss: 1.3015, D(x): 0.71, D(G(z)): 0.33
# Epoch [206/300], Step [400/600], d_loss: 0.9011, g_loss: 1.6801, D(x): 0.68, D(G(z)): 0.27
# Epoch [206/300], Step [600/600], d_loss: 0.9097, g_loss: 1.7277, D(x): 0.66, D(G(z)): 0.26
# Saving fake_images-0207.png
# Epoch [207/300], Step [200/600], d_loss: 1.0220, g_loss: 1.3236, D(x): 0.65, D(G(z)): 0.30
# Epoch [207/300], Step [400/600], d_loss: 1.4276, g_loss: 1.3940, D(x): 0.67, D(G(z)): 0.49
# Epoch [207/300], Step [600/600], d_loss: 1.0380, g_loss: 1.5438, D(x): 0.66, D(G(z)): 0.32
# Saving fake_images-0208.png
# Epoch [208/300], Step [200/600], d_loss: 0.8554, g_loss: 1.7773, D(x): 0.69, D(G(z)): 0.28
# Epoch [208/300], Step [400/600], d_loss: 0.7324, g_loss: 1.5148, D(x): 0.77, D(G(z)): 0.28
# Epoch [208/300], Step [600/600], d_loss: 0.9169, g_loss: 1.5120, D(x): 0.69, D(G(z)): 0.29
# Saving fake_images-0209.png
# Epoch [209/300], Step [200/600], d_loss: 0.8561, g_loss: 1.4999, D(x): 0.71, D(G(z)): 0.29
# Epoch [209/300], Step [400/600], d_loss: 0.8906, g_loss: 1.3474, D(x): 0.70, D(G(z)): 0.29
# Epoch [209/300], Step [600/600], d_loss: 0.8477, g_loss: 1.6798, D(x): 0.68, D(G(z)): 0.23
# Saving fake_images-0210.png
# Epoch [210/300], Step [200/600], d_loss: 0.7962, g_loss: 1.1669, D(x): 0.68, D(G(z)): 0.24
# Epoch [210/300], Step [400/600], d_loss: 0.7977, g_loss: 1.5606, D(x): 0.73, D(G(z)): 0.26
# Epoch [210/300], Step [600/600], d_loss: 0.9265, g_loss: 1.2593, D(x): 0.71, D(G(z)): 0.36
# Saving fake_images-0211.png
# Epoch [211/300], Step [200/600], d_loss: 1.0350, g_loss: 1.9603, D(x): 0.71, D(G(z)): 0.35
# Epoch [211/300], Step [400/600], d_loss: 1.1529, g_loss: 1.7221, D(x): 0.55, D(G(z)): 0.23
# Epoch [211/300], Step [600/600], d_loss: 0.9179, g_loss: 1.4321, D(x): 0.77, D(G(z)): 0.37
# Saving fake_images-0212.png
# Epoch [212/300], Step [200/600], d_loss: 0.9720, g_loss: 1.4724, D(x): 0.66, D(G(z)): 0.31
# Epoch [212/300], Step [400/600], d_loss: 0.9051, g_loss: 1.3208, D(x): 0.72, D(G(z)): 0.31
# Epoch [212/300], Step [600/600], d_loss: 0.9776, g_loss: 1.5202, D(x): 0.65, D(G(z)): 0.29
# Saving fake_images-0213.png
# Epoch [213/300], Step [200/600], d_loss: 0.9292, g_loss: 1.3148, D(x): 0.71, D(G(z)): 0.33
# Epoch [213/300], Step [400/600], d_loss: 1.1862, g_loss: 1.2656, D(x): 0.62, D(G(z)): 0.35
# Epoch [213/300], Step [600/600], d_loss: 0.9404, g_loss: 1.3860, D(x): 0.70, D(G(z)): 0.34
# Saving fake_images-0214.png
# Epoch [214/300], Step [200/600], d_loss: 0.9442, g_loss: 1.5066, D(x): 0.69, D(G(z)): 0.32
# Epoch [214/300], Step [400/600], d_loss: 1.1564, g_loss: 1.4646, D(x): 0.59, D(G(z)): 0.28
# Epoch [214/300], Step [600/600], d_loss: 1.1240, g_loss: 1.2305, D(x): 0.71, D(G(z)): 0.41
# Saving fake_images-0215.png
# Epoch [215/300], Step [200/600], d_loss: 1.0408, g_loss: 1.2229, D(x): 0.68, D(G(z)): 0.35
# Epoch [215/300], Step [400/600], d_loss: 1.0468, g_loss: 1.1181, D(x): 0.73, D(G(z)): 0.40
# Epoch [215/300], Step [600/600], d_loss: 0.8867, g_loss: 1.4469, D(x): 0.79, D(G(z)): 0.40
# Saving fake_images-0216.png
# Epoch [216/300], Step [200/600], d_loss: 0.8256, g_loss: 1.9412, D(x): 0.70, D(G(z)): 0.25
# Epoch [216/300], Step [400/600], d_loss: 0.9203, g_loss: 1.6628, D(x): 0.70, D(G(z)): 0.30
# Epoch [216/300], Step [600/600], d_loss: 0.9882, g_loss: 1.8213, D(x): 0.64, D(G(z)): 0.28
# Saving fake_images-0217.png
# Epoch [217/300], Step [200/600], d_loss: 1.1877, g_loss: 1.1350, D(x): 0.68, D(G(z)): 0.41
# Epoch [217/300], Step [400/600], d_loss: 1.0918, g_loss: 1.6130, D(x): 0.58, D(G(z)): 0.27
# Epoch [217/300], Step [600/600], d_loss: 1.0136, g_loss: 1.3930, D(x): 0.67, D(G(z)): 0.32
# Saving fake_images-0218.png
# Epoch [218/300], Step [200/600], d_loss: 1.0003, g_loss: 1.2460, D(x): 0.74, D(G(z)): 0.38
# Epoch [218/300], Step [400/600], d_loss: 1.0118, g_loss: 1.3748, D(x): 0.71, D(G(z)): 0.36
# Epoch [218/300], Step [600/600], d_loss: 0.7341, g_loss: 1.5671, D(x): 0.75, D(G(z)): 0.27
# Saving fake_images-0219.png
# Epoch [219/300], Step [200/600], d_loss: 1.0519, g_loss: 1.5568, D(x): 0.57, D(G(z)): 0.24
# Epoch [219/300], Step [400/600], d_loss: 0.9150, g_loss: 1.6371, D(x): 0.69, D(G(z)): 0.30
# Epoch [219/300], Step [600/600], d_loss: 0.8507, g_loss: 1.4104, D(x): 0.72, D(G(z)): 0.31
# Saving fake_images-0220.png
# Epoch [220/300], Step [200/600], d_loss: 0.9911, g_loss: 1.6433, D(x): 0.65, D(G(z)): 0.28
# Epoch [220/300], Step [400/600], d_loss: 0.9579, g_loss: 1.5148, D(x): 0.64, D(G(z)): 0.24
# Epoch [220/300], Step [600/600], d_loss: 0.9125, g_loss: 1.2801, D(x): 0.74, D(G(z)): 0.36
# Saving fake_images-0221.png
# Epoch [221/300], Step [200/600], d_loss: 1.0079, g_loss: 1.5353, D(x): 0.64, D(G(z)): 0.31
# Epoch [221/300], Step [400/600], d_loss: 0.8723, g_loss: 1.3947, D(x): 0.68, D(G(z)): 0.29
# Epoch [221/300], Step [600/600], d_loss: 1.0054, g_loss: 1.5823, D(x): 0.61, D(G(z)): 0.26
# Saving fake_images-0222.png
# Epoch [222/300], Step [200/600], d_loss: 1.1422, g_loss: 1.5410, D(x): 0.53, D(G(z)): 0.20
# Epoch [222/300], Step [400/600], d_loss: 0.9625, g_loss: 1.5168, D(x): 0.63, D(G(z)): 0.27
# Epoch [222/300], Step [600/600], d_loss: 1.0602, g_loss: 1.5179, D(x): 0.68, D(G(z)): 0.35
# Saving fake_images-0223.png
# Epoch [223/300], Step [200/600], d_loss: 0.9337, g_loss: 1.7040, D(x): 0.69, D(G(z)): 0.29
# Epoch [223/300], Step [400/600], d_loss: 0.9783, g_loss: 1.3522, D(x): 0.72, D(G(z)): 0.36
# Epoch [223/300], Step [600/600], d_loss: 0.8049, g_loss: 1.4632, D(x): 0.74, D(G(z)): 0.30
# Saving fake_images-0224.png
# Epoch [224/300], Step [200/600], d_loss: 1.0160, g_loss: 1.1495, D(x): 0.72, D(G(z)): 0.38
# Epoch [224/300], Step [400/600], d_loss: 0.9395, g_loss: 1.5281, D(x): 0.68, D(G(z)): 0.30
# Epoch [224/300], Step [600/600], d_loss: 1.0172, g_loss: 1.5667, D(x): 0.67, D(G(z)): 0.32
# Saving fake_images-0225.png
# Epoch [225/300], Step [200/600], d_loss: 0.8717, g_loss: 1.6205, D(x): 0.69, D(G(z)): 0.26
# Epoch [225/300], Step [400/600], d_loss: 1.0046, g_loss: 1.8967, D(x): 0.69, D(G(z)): 0.34
# Epoch [225/300], Step [600/600], d_loss: 1.0993, g_loss: 1.5753, D(x): 0.53, D(G(z)): 0.18
# Saving fake_images-0226.png
# Epoch [226/300], Step [200/600], d_loss: 0.7845, g_loss: 1.3864, D(x): 0.73, D(G(z)): 0.29
# Epoch [226/300], Step [400/600], d_loss: 0.9506, g_loss: 1.9077, D(x): 0.64, D(G(z)): 0.27
# Epoch [226/300], Step [600/600], d_loss: 0.7798, g_loss: 1.5927, D(x): 0.69, D(G(z)): 0.25
# Saving fake_images-0227.png
# Epoch [227/300], Step [200/600], d_loss: 0.9999, g_loss: 1.6149, D(x): 0.72, D(G(z)): 0.38
# Epoch [227/300], Step [400/600], d_loss: 0.8800, g_loss: 1.1486, D(x): 0.77, D(G(z)): 0.37
# Epoch [227/300], Step [600/600], d_loss: 0.9094, g_loss: 1.7398, D(x): 0.69, D(G(z)): 0.31
# Saving fake_images-0228.png
# Epoch [228/300], Step [200/600], d_loss: 0.9378, g_loss: 1.5553, D(x): 0.72, D(G(z)): 0.35
# Epoch [228/300], Step [400/600], d_loss: 1.0585, g_loss: 1.7537, D(x): 0.65, D(G(z)): 0.30
# Epoch [228/300], Step [600/600], d_loss: 0.9006, g_loss: 1.6504, D(x): 0.66, D(G(z)): 0.26
# Saving fake_images-0229.png
# Epoch [229/300], Step [200/600], d_loss: 0.9314, g_loss: 1.3661, D(x): 0.68, D(G(z)): 0.32
# Epoch [229/300], Step [400/600], d_loss: 1.0000, g_loss: 1.3721, D(x): 0.62, D(G(z)): 0.27
# Epoch [229/300], Step [600/600], d_loss: 1.0196, g_loss: 1.8411, D(x): 0.63, D(G(z)): 0.27
# Saving fake_images-0230.png
# Epoch [230/300], Step [200/600], d_loss: 0.9617, g_loss: 1.4984, D(x): 0.70, D(G(z)): 0.34
# Epoch [230/300], Step [400/600], d_loss: 0.9452, g_loss: 1.5391, D(x): 0.69, D(G(z)): 0.30
# Epoch [230/300], Step [600/600], d_loss: 0.9146, g_loss: 1.3578, D(x): 0.77, D(G(z)): 0.36
# Saving fake_images-0231.png
# Epoch [231/300], Step [200/600], d_loss: 0.9821, g_loss: 1.9023, D(x): 0.64, D(G(z)): 0.27
# Epoch [231/300], Step [400/600], d_loss: 0.8650, g_loss: 1.3076, D(x): 0.65, D(G(z)): 0.24
# Epoch [231/300], Step [600/600], d_loss: 1.0525, g_loss: 1.5268, D(x): 0.65, D(G(z)): 0.31
# Saving fake_images-0232.png
# Epoch [232/300], Step [200/600], d_loss: 0.9367, g_loss: 1.2493, D(x): 0.71, D(G(z)): 0.35
# Epoch [232/300], Step [400/600], d_loss: 1.0296, g_loss: 1.5869, D(x): 0.69, D(G(z)): 0.36
# Epoch [232/300], Step [600/600], d_loss: 1.0557, g_loss: 1.3169, D(x): 0.62, D(G(z)): 0.30
# Saving fake_images-0233.png
# Epoch [233/300], Step [200/600], d_loss: 0.9118, g_loss: 1.5601, D(x): 0.73, D(G(z)): 0.34
# Epoch [233/300], Step [400/600], d_loss: 0.8260, g_loss: 1.9792, D(x): 0.68, D(G(z)): 0.22
# Epoch [233/300], Step [600/600], d_loss: 0.8442, g_loss: 1.4314, D(x): 0.78, D(G(z)): 0.35
# Saving fake_images-0234.png
# Epoch [234/300], Step [200/600], d_loss: 0.9384, g_loss: 2.0755, D(x): 0.71, D(G(z)): 0.34
# Epoch [234/300], Step [400/600], d_loss: 0.9430, g_loss: 1.7297, D(x): 0.71, D(G(z)): 0.32
# Epoch [234/300], Step [600/600], d_loss: 0.9218, g_loss: 1.5374, D(x): 0.68, D(G(z)): 0.30
# Saving fake_images-0235.png
# Epoch [235/300], Step [200/600], d_loss: 0.8918, g_loss: 1.6059, D(x): 0.65, D(G(z)): 0.25
# Epoch [235/300], Step [400/600], d_loss: 1.0416, g_loss: 1.7228, D(x): 0.62, D(G(z)): 0.25
# Epoch [235/300], Step [600/600], d_loss: 0.8634, g_loss: 1.5865, D(x): 0.70, D(G(z)): 0.30
# Saving fake_images-0236.png
# Epoch [236/300], Step [200/600], d_loss: 0.7980, g_loss: 1.7963, D(x): 0.67, D(G(z)): 0.21
# Epoch [236/300], Step [400/600], d_loss: 1.0096, g_loss: 1.3255, D(x): 0.68, D(G(z)): 0.32
# Epoch [236/300], Step [600/600], d_loss: 0.9369, g_loss: 1.6483, D(x): 0.75, D(G(z)): 0.36
# Saving fake_images-0237.png
# Epoch [237/300], Step [200/600], d_loss: 0.7736, g_loss: 1.5749, D(x): 0.74, D(G(z)): 0.25
# Epoch [237/300], Step [400/600], d_loss: 0.9511, g_loss: 1.4558, D(x): 0.68, D(G(z)): 0.30
# Epoch [237/300], Step [600/600], d_loss: 0.9426, g_loss: 1.7732, D(x): 0.62, D(G(z)): 0.23
# Saving fake_images-0238.png
# Epoch [238/300], Step [200/600], d_loss: 0.8779, g_loss: 1.4655, D(x): 0.71, D(G(z)): 0.32
# Epoch [238/300], Step [400/600], d_loss: 0.8258, g_loss: 1.6336, D(x): 0.72, D(G(z)): 0.30
# Epoch [238/300], Step [600/600], d_loss: 0.9339, g_loss: 1.5049, D(x): 0.75, D(G(z)): 0.37
# Saving fake_images-0239.png
# Epoch [239/300], Step [200/600], d_loss: 0.9812, g_loss: 1.4071, D(x): 0.68, D(G(z)): 0.34
# Epoch [239/300], Step [400/600], d_loss: 0.8804, g_loss: 1.0985, D(x): 0.68, D(G(z)): 0.29
# Epoch [239/300], Step [600/600], d_loss: 0.7994, g_loss: 1.7841, D(x): 0.68, D(G(z)): 0.23
# Saving fake_images-0240.png
# Epoch [240/300], Step [200/600], d_loss: 0.9984, g_loss: 1.2090, D(x): 0.70, D(G(z)): 0.36
# Epoch [240/300], Step [400/600], d_loss: 0.8685, g_loss: 1.5142, D(x): 0.74, D(G(z)): 0.34
# Epoch [240/300], Step [600/600], d_loss: 0.8182, g_loss: 1.6132, D(x): 0.79, D(G(z)): 0.35
# Saving fake_images-0241.png
# Epoch [241/300], Step [200/600], d_loss: 0.7931, g_loss: 1.5927, D(x): 0.71, D(G(z)): 0.29
# Epoch [241/300], Step [400/600], d_loss: 0.9720, g_loss: 1.7070, D(x): 0.63, D(G(z)): 0.27
# Epoch [241/300], Step [600/600], d_loss: 0.9031, g_loss: 1.9479, D(x): 0.77, D(G(z)): 0.36
# Saving fake_images-0242.png
# Epoch [242/300], Step [200/600], d_loss: 0.8017, g_loss: 1.7906, D(x): 0.74, D(G(z)): 0.30
# Epoch [242/300], Step [400/600], d_loss: 0.8988, g_loss: 2.0084, D(x): 0.71, D(G(z)): 0.29
# Epoch [242/300], Step [600/600], d_loss: 0.9938, g_loss: 1.4567, D(x): 0.66, D(G(z)): 0.28
# Saving fake_images-0243.png
# Epoch [243/300], Step [200/600], d_loss: 1.0502, g_loss: 1.4965, D(x): 0.67, D(G(z)): 0.36
# Epoch [243/300], Step [400/600], d_loss: 0.9263, g_loss: 1.6088, D(x): 0.73, D(G(z)): 0.34
# Epoch [243/300], Step [600/600], d_loss: 1.0142, g_loss: 1.4837, D(x): 0.67, D(G(z)): 0.32
# Saving fake_images-0244.png
# Epoch [244/300], Step [200/600], d_loss: 1.0289, g_loss: 1.2135, D(x): 0.71, D(G(z)): 0.40
# Epoch [244/300], Step [400/600], d_loss: 0.7723, g_loss: 1.4289, D(x): 0.73, D(G(z)): 0.26
# Epoch [244/300], Step [600/600], d_loss: 0.8487, g_loss: 1.6971, D(x): 0.70, D(G(z)): 0.27
# Saving fake_images-0245.png
# Epoch [245/300], Step [200/600], d_loss: 1.0213, g_loss: 1.3714, D(x): 0.69, D(G(z)): 0.35
# Epoch [245/300], Step [400/600], d_loss: 0.8515, g_loss: 1.7393, D(x): 0.65, D(G(z)): 0.21
# Epoch [245/300], Step [600/600], d_loss: 1.0547, g_loss: 0.8957, D(x): 0.61, D(G(z)): 0.32
# Saving fake_images-0246.png
# Epoch [246/300], Step [200/600], d_loss: 0.8783, g_loss: 1.3669, D(x): 0.65, D(G(z)): 0.26
# Epoch [246/300], Step [400/600], d_loss: 1.0157, g_loss: 1.6246, D(x): 0.65, D(G(z)): 0.30
# Epoch [246/300], Step [600/600], d_loss: 0.9105, g_loss: 1.3852, D(x): 0.76, D(G(z)): 0.37
# Saving fake_images-0247.png
# Epoch [247/300], Step [200/600], d_loss: 0.8016, g_loss: 1.5213, D(x): 0.74, D(G(z)): 0.31
# Epoch [247/300], Step [400/600], d_loss: 0.8262, g_loss: 1.3485, D(x): 0.76, D(G(z)): 0.34
# Epoch [247/300], Step [600/600], d_loss: 0.9813, g_loss: 1.5499, D(x): 0.72, D(G(z)): 0.36
# Saving fake_images-0248.png
# Epoch [248/300], Step [200/600], d_loss: 0.7408, g_loss: 1.9581, D(x): 0.71, D(G(z)): 0.21
# Epoch [248/300], Step [400/600], d_loss: 0.8133, g_loss: 1.3854, D(x): 0.77, D(G(z)): 0.33
# Epoch [248/300], Step [600/600], d_loss: 1.0060, g_loss: 1.8122, D(x): 0.63, D(G(z)): 0.28
# Saving fake_images-0249.png
# Epoch [249/300], Step [200/600], d_loss: 1.1114, g_loss: 1.1712, D(x): 0.69, D(G(z)): 0.41
# Epoch [249/300], Step [400/600], d_loss: 0.8859, g_loss: 1.5974, D(x): 0.63, D(G(z)): 0.24
# Epoch [249/300], Step [600/600], d_loss: 0.9170, g_loss: 1.8136, D(x): 0.72, D(G(z)): 0.31
# Saving fake_images-0250.png
# Epoch [250/300], Step [200/600], d_loss: 1.0978, g_loss: 1.6011, D(x): 0.66, D(G(z)): 0.38
# Epoch [250/300], Step [400/600], d_loss: 0.8824, g_loss: 1.5517, D(x): 0.73, D(G(z)): 0.34
# Epoch [250/300], Step [600/600], d_loss: 1.0100, g_loss: 1.5411, D(x): 0.65, D(G(z)): 0.33
# Saving fake_images-0251.png
# Epoch [251/300], Step [200/600], d_loss: 0.9868, g_loss: 1.6978, D(x): 0.67, D(G(z)): 0.31
# Epoch [251/300], Step [400/600], d_loss: 0.9462, g_loss: 1.6021, D(x): 0.68, D(G(z)): 0.31
# Epoch [251/300], Step [600/600], d_loss: 0.8913, g_loss: 1.6374, D(x): 0.79, D(G(z)): 0.37
# Saving fake_images-0252.png
# Epoch [252/300], Step [200/600], d_loss: 0.8315, g_loss: 1.3223, D(x): 0.77, D(G(z)): 0.34
# Epoch [252/300], Step [400/600], d_loss: 0.8785, g_loss: 1.8209, D(x): 0.65, D(G(z)): 0.26
# Epoch [252/300], Step [600/600], d_loss: 1.0168, g_loss: 1.3630, D(x): 0.72, D(G(z)): 0.37
# Saving fake_images-0253.png
# Epoch [253/300], Step [200/600], d_loss: 0.7295, g_loss: 1.3812, D(x): 0.73, D(G(z)): 0.25
# Epoch [253/300], Step [400/600], d_loss: 1.0354, g_loss: 1.6200, D(x): 0.64, D(G(z)): 0.30
# Epoch [253/300], Step [600/600], d_loss: 0.9847, g_loss: 1.1763, D(x): 0.65, D(G(z)): 0.28
# Saving fake_images-0254.png
# Epoch [254/300], Step [200/600], d_loss: 0.9318, g_loss: 1.2748, D(x): 0.66, D(G(z)): 0.28
# Epoch [254/300], Step [400/600], d_loss: 1.1460, g_loss: 1.3825, D(x): 0.58, D(G(z)): 0.31
# Epoch [254/300], Step [600/600], d_loss: 0.7234, g_loss: 1.8545, D(x): 0.71, D(G(z)): 0.22
# Saving fake_images-0255.png
# Epoch [255/300], Step [200/600], d_loss: 0.9937, g_loss: 1.7318, D(x): 0.59, D(G(z)): 0.21
# Epoch [255/300], Step [400/600], d_loss: 0.9035, g_loss: 1.4177, D(x): 0.67, D(G(z)): 0.25
# Epoch [255/300], Step [600/600], d_loss: 0.9133, g_loss: 1.4933, D(x): 0.69, D(G(z)): 0.26
# Saving fake_images-0256.png
# Epoch [256/300], Step [200/600], d_loss: 0.8806, g_loss: 1.8628, D(x): 0.68, D(G(z)): 0.23
# Epoch [256/300], Step [400/600], d_loss: 0.8292, g_loss: 1.6947, D(x): 0.68, D(G(z)): 0.25
# Epoch [256/300], Step [600/600], d_loss: 0.7936, g_loss: 1.6528, D(x): 0.68, D(G(z)): 0.22
# Saving fake_images-0257.png
# Epoch [257/300], Step [200/600], d_loss: 0.8737, g_loss: 1.3275, D(x): 0.72, D(G(z)): 0.31
# Epoch [257/300], Step [400/600], d_loss: 0.8148, g_loss: 1.5804, D(x): 0.72, D(G(z)): 0.27
# Epoch [257/300], Step [600/600], d_loss: 1.0570, g_loss: 1.1800, D(x): 0.73, D(G(z)): 0.38
# Saving fake_images-0258.png
# Epoch [258/300], Step [200/600], d_loss: 0.9083, g_loss: 1.5135, D(x): 0.69, D(G(z)): 0.30
# Epoch [258/300], Step [400/600], d_loss: 0.9110, g_loss: 1.3643, D(x): 0.69, D(G(z)): 0.29
# Epoch [258/300], Step [600/600], d_loss: 0.9046, g_loss: 1.6407, D(x): 0.65, D(G(z)): 0.25
# Saving fake_images-0259.png

# %% [markdown]
# Now that we have trained the models, we can save checkpoints.

# %%
# Save the model checkpoints 
torch.save(G.state_dict(), 'G.ckpt')
torch.save(D.state_dict(), 'D.ckpt')

# %% [markdown]
# Here's how the generated images look, after the 10th, 50th, 100th and 300th epochs of training.

# %%
Image('./samples/fake_images-0010.png')

# %%
Image('./samples/fake_images-0050.png')

# %%
Image('./samples/fake_images-0100.png')

# %%
Image('./samples/fake_images-0300.png')

# %% [markdown]
# We can visualize the training process by combining the sample images generated after each epoch into a video using OpenCV.

# %%
import cv2
import os
from IPython.display import FileLink

vid_fname = 'gans_training.avi'

files = [os.path.join(sample_dir, f) for f in os.listdir(sample_dir) if 'fake_images' in f]
files.sort()

out = cv2.VideoWriter(vid_fname,cv2.VideoWriter_fourcc(*'MP4V'), 8, (302,302))
[out.write(cv2.imread(fname)) for fname in files]
out.release()
FileLink('gans_training.avi')

# %% [markdown]
# You can view the animated training video here: https://www.youtube.com/watch?v=R7HTX79JlBg
#
# We can also visualize how the loss changes over time. Visualizing losses is quite useful for debugging the training process. For GANs, we expect the generator's loss to reduce over time, without the discriminator's loss getting too high.

# %%
plt.plot(d_losses, '-')
plt.plot(g_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');

# %%
plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');

# %% [markdown]
# ## Save and Commit
#
# We can caputre a snapshot of our work (including the Jupyter notebook, sample images and trained models) using the `jovian` Python library.

# %%
# Install the library
# !pip install jovian --upgrade -q

# %%
# Import the library
import jovian

# %%
jovian.commit(outputs=['samples/fake_images-0000.png', 
                       'samples/fake_images-0010.png', 
                       'samples/fake_images-0025.png', 
                       'samples/fake_images-0050.png', 
                       'samples/fake_images-0100.png', 
                       'samples/fake_images-0150.png', 
                       'samples/fake_images-0200.png', 
                       'samples/fake_images-0250.png', 
                       'samples/fake_images-0300.png', 
                       'gans_training.avi'], 
              project='06-mnist-gan')

# %% [markdown]
# Running `jovian.commit` uploads the Jupyter notebook and the associated files to your [Jovian.ml](https://www.jovian.ml) account. You can share the project online publicly, or collaborate privately with your friends & colleagues. Jovian also automatically captures the Python environment (dependencies & library versions), so that you & others can reproduce your work easily. Jovian also includes a powerful commenting interface for discussion. To learn more visit [www.jovian.ml](https://www.jovian.ml).
#
# <img src="https://i.imgur.com/KVjXpd6.png">
